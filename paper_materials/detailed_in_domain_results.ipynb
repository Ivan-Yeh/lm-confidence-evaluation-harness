# %%
import os
import pandas as pd
import numpy as np

# %%
methods_names = {
    "dist_linguistic_confidence": "Dist. Ling. Conf.",
    "dist_semantic_uncertainty": "Dist. Semantic Unc.",
    "dist_lnll": "Dist. Token Prob"
}

dataset_size = {
    "mmlu": 116000,
    "squadv2": 130000,
    "truthful_qa": 817
}

dataset_map = {
    "mmlu": "MMLU",
    "squadv2": "SQuAD2.0",
    "truthful_qa": "TruthfulQA"
}

model_name_map = {
    "Llama-3.1-8B-Instruct": "Llama-3.1-8B-Inst.",
    "Meta-Llama-3-8B-Instruct": "Llama-3-8B-Inst.",
    "Qwen2.5-7B-Instruct": "Qwen2.5-7B-Inst.",
    "Qwen3-8B": "Qwen3-8B-Inst.",
    "Mistral-7B-Instruct-v0.3": "Mistral-7B-Inst.",
    "gpt-oss-20b": "GPT-OSS-20B",
}

# %%
prompt_type = "direct_qa"
results_dir = f"/hdd/ivny/{prompt_type}_in_domain_calibration"

# list all leaf nodes in results_dir
leaf_dirs = []
for root, dirs, files in os.walk(results_dir):
    if not dirs:  # if there are no subdirectories, it's a leaf node
        leaf_dirs.append(root)

all_records = []
for leaf_dir in leaf_dirs:
    _, _, _, _, dataset_name, _, model_name = leaf_dir.split("/")
    if os.path.exists(os.path.join(leaf_dir, "calibration_performance.csv")):
        csv_data = pd.read_csv(os.path.join(leaf_dir, "calibration_performance.csv"), index_col=0)
        csv_records = csv_data.transpose().to_dict("records")

        for record in csv_records:
            record["dataset"] = dataset_map.get(dataset_name, dataset_name)
            record["model"] = model_name_map.get(model_name, model_name)
            record["dataset_size"] = dataset_size.get(dataset_name, None)

        all_records.extend(csv_records)
    else:
        print(model_name, dataset_name, "missing calibration_performance.csv")

# %%
full_df = pd.DataFrame(all_records)
full_df
# Out:
#     original_lc_generalised_ECE  original_lc_faithfulness_divergence  \
# 0                      0.413939                             3.274456
# 1                      0.374258                             2.628490
# 2                      0.306621                             2.156529
# 3                      0.349312                             2.606174
# 4                      0.232663                             2.837246
# 5                      0.322834                             1.716467
# 6                      0.217603                             1.379232
# 7                      0.202932                             1.175403
# 8                      0.393695                             2.560467
# 9                      0.358210                             2.150989
# 10                     0.357889                             2.100883
# 11                     0.442049                             2.566869
#
#     original_lc_ece_mean  original_lc_dAUROC  original_lc_auroc_mean  \
# 0               0.395699             0.50020                0.503842
# 1               0.362216             0.51790                0.524924
# 2               0.296183             0.54920                0.566522
# 3               0.340447             0.51190                0.518984
# 4               0.180036             0.48875                0.489187
# 5               0.261834             0.47380                0.462672
# 6               0.188021             0.57880                0.605029
# 7               0.142476             0.51830                0.539133
# 8               0.384898             0.57530                0.612122
# 9               0.349199             0.57000                0.585261
# 10              0.353123             0.56850                0.594945
# 11              0.441812             0.57310                0.626814
#
#     original_tp_generalised_ECE  original_tp_faithfulness_divergence  \
# 0                      0.211727                             0.709649
# 1                      0.277514                             2.810614
# 2                      0.132850                             0.631956
# 3                      0.388878                            45.867489
# 4                      0.149702                             2.083979
# 5                      0.312549                            88.616659
# 6                      0.155328                             0.432368
# 7                      0.272198                           280.166764
# 8                      0.101684                             0.542667
# 9                      0.146225                             0.671835
# 10                     0.050197                             0.473037
# 11                     0.427672                            25.753791
#
#     original_tp_ece_mean  original_tp_dAUROC  original_tp_auroc_mean  ...  \
# 0               0.209470             0.62040                0.671092  ...
# 1               0.276868             0.65100                0.694870  ...
# 2               0.113532             0.68700                0.733780  ...
# 3               0.388661             0.65265                0.688362  ...
# 4               0.087214             0.49680                0.499500  ...
# 5               0.306756             0.60735                0.624988  ...
# 6               0.130197             0.61010                0.698521  ...
# 7               0.269200             0.58335                0.570269  ...
# 8               0.091167             0.59320                0.626063  ...
# 9               0.116989             0.51950                0.519139  ...
# 10              0.068014             0.64450                0.713940  ...
# 11              0.427671             0.58710                0.611500  ...
#
#     calibrated_tp_rewritten_lc_dAUROC  calibrated_tp_rewritten_lc_auroc_mean  \
# 0                              0.5651                               0.604101
# 1                              0.5717                               0.625023
# 2                              0.6262                               0.669447
# 3                              0.5388                               0.555123
# 4                              0.5219                               0.518189
# 5                              0.5512                               0.582352
# 6                              0.6241                               0.666601
# 7                              0.5192                               0.546945
# 8                              0.5909                               0.646440
# 9                              0.5215                               0.539943
# 10                             0.5690                               0.617572
# 11                             0.5509                               0.588525
#
#     calibrated_su_rewritten_lc_generalised_ECE  \
# 0                                     0.164925
# 1                                     0.166311
# 2                                     0.116859
# 3                                     0.146888
# 4                                     0.126476
# 5                                     0.132306
# 6                                     0.104283
# 7                                     0.102226
# 8                                     0.201807
# 9                                     0.176889
# 10                                    0.168059
# 11                                    0.191303
#
#     calibrated_su_rewritten_lc_faithfulness_divergence  \
# 0                                            0.643274
# 1                                            0.668390
# 2                                            0.617548
# 3                                            0.640668
# 4                                            0.475499
# 5                                            0.502037
# 6                                            0.621727
# 7                                            0.592725
# 8                                            0.651611
# 9                                            0.617369
# 10                                           0.570702
# 11                                           0.590264
#
#     calibrated_su_rewritten_lc_ece_mean  calibrated_su_rewritten_lc_dAUROC  \
# 0                              0.155648                             0.6023
# 1                              0.141688                             0.5377
# 2                              0.100706                             0.5606
# 3                              0.116548                             0.5479
# 4                              0.053905                             0.6441
# 5                              0.072146                             0.5327
# 6                              0.085277                             0.6668
# 7                              0.044590                             0.5624
# 8                              0.196160                             0.6170
# 9                              0.176902                             0.6172
# 10                             0.127107                             0.5274
# 11                             0.180934                             0.5678
#
#     calibrated_su_rewritten_lc_auroc_mean     dataset               model  \
# 0                                0.639329    SQuAD2.0         GPT-OSS-20B
# 1                                0.566120    SQuAD2.0    Mistral-7B-Inst.
# 2                                0.604327    SQuAD2.0  Llama-3.1-8B-Inst.
# 3                                0.571994    SQuAD2.0      Qwen3-8B-Inst.
# 4                                0.666217        MMLU         GPT-OSS-20B
# 5                                0.555023        MMLU    Mistral-7B-Inst.
# 6                                0.716231        MMLU  Llama-3.1-8B-Inst.
# 7                                0.587880        MMLU      Qwen3-8B-Inst.
# 8                                0.652594  TruthfulQA         GPT-OSS-20B
# 9                                0.656544  TruthfulQA    Mistral-7B-Inst.
# 10                               0.553557  TruthfulQA  Llama-3.1-8B-Inst.
# 11                               0.614632  TruthfulQA      Qwen3-8B-Inst.
#
#     dataset_size
# 0         130000
# 1         130000
# 2         130000
# 3         130000
# 4         116000
# 5         116000
# 6         116000
# 7         116000
# 8            817
# 9            817
# 10           817
# 11           817
#
# [12 rows x 48 columns]

# %%
full_df.columns
# Out:
# Index(['original_lc_generalised_ECE', 'original_lc_faithfulness_divergence',
#        'original_lc_ece_mean', 'original_lc_dAUROC', 'original_lc_auroc_mean',
#        'original_tp_generalised_ECE', 'original_tp_faithfulness_divergence',
#        'original_tp_ece_mean', 'original_tp_dAUROC', 'original_tp_auroc_mean',
#        'original_su_generalised_ECE', 'original_su_faithfulness_divergence',
#        'original_su_ece_mean', 'original_su_dAUROC', 'original_su_auroc_mean',
#        'calibrated_lc_generalised_ECE',
#        'calibrated_lc_faithfulness_divergence', 'calibrated_lc_ece_mean',
#        'calibrated_lc_dAUROC', 'calibrated_lc_auroc_mean',
#        'calibrated_tp_generalised_ECE',
#        'calibrated_tp_faithfulness_divergence', 'calibrated_tp_ece_mean',
#        'calibrated_tp_dAUROC', 'calibrated_tp_auroc_mean',
#        'calibrated_su_generalised_ECE',
#        'calibrated_su_faithfulness_divergence', 'calibrated_su_ece_mean',
#        'calibrated_su_dAUROC', 'calibrated_su_auroc_mean',
#        'calibrated_lc_rewritten_lc_generalised_ECE',
#        'calibrated_lc_rewritten_lc_faithfulness_divergence',
#        'calibrated_lc_rewritten_lc_ece_mean',
#        'calibrated_lc_rewritten_lc_dAUROC',
#        'calibrated_lc_rewritten_lc_auroc_mean',
#        'calibrated_tp_rewritten_lc_generalised_ECE',
#        'calibrated_tp_rewritten_lc_faithfulness_divergence',
#        'calibrated_tp_rewritten_lc_ece_mean',
#        'calibrated_tp_rewritten_lc_dAUROC',
#        'calibrated_tp_rewritten_lc_auroc_mean',
#        'calibrated_su_rewritten_lc_generalised_ECE',
#        'calibrated_su_rewritten_lc_faithfulness_divergence',
#        'calibrated_su_rewritten_lc_ece_mean',
#        'calibrated_su_rewritten_lc_dAUROC',
#        'calibrated_su_rewritten_lc_auroc_mean', 'dataset', 'model',
#        'dataset_size'],
#       dtype='str')

# %%
in_domain_detailed_records = []

for _, record in full_df.iterrows():
    lc = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Linguistic Confidence",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_lc_rewritten_lc_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_lc_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(lc)
    su = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Semantic Uncertainty",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_su_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_su_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(su)
    tp = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Token Probability",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_tp_rewritten_lc_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_tp_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(tp)

# %%
in_domain_df = pd.DataFrame(in_domain_detailed_records)
in_domain_df
# Out:
#        Dataset               Model              Estimator  \
# 0     SQuAD2.0         GPT-OSS-20B  Linguistic Confidence
# 1     SQuAD2.0         GPT-OSS-20B   Semantic Uncertainty
# 2     SQuAD2.0         GPT-OSS-20B      Token Probability
# 3     SQuAD2.0    Mistral-7B-Inst.  Linguistic Confidence
# 4     SQuAD2.0    Mistral-7B-Inst.   Semantic Uncertainty
# 5     SQuAD2.0    Mistral-7B-Inst.      Token Probability
# 6     SQuAD2.0  Llama-3.1-8B-Inst.  Linguistic Confidence
# 7     SQuAD2.0  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 8     SQuAD2.0  Llama-3.1-8B-Inst.      Token Probability
# 9     SQuAD2.0      Qwen3-8B-Inst.  Linguistic Confidence
# 10    SQuAD2.0      Qwen3-8B-Inst.   Semantic Uncertainty
# 11    SQuAD2.0      Qwen3-8B-Inst.      Token Probability
# 12        MMLU         GPT-OSS-20B  Linguistic Confidence
# 13        MMLU         GPT-OSS-20B   Semantic Uncertainty
# 14        MMLU         GPT-OSS-20B      Token Probability
# 15        MMLU    Mistral-7B-Inst.  Linguistic Confidence
# 16        MMLU    Mistral-7B-Inst.   Semantic Uncertainty
# 17        MMLU    Mistral-7B-Inst.      Token Probability
# 18        MMLU  Llama-3.1-8B-Inst.  Linguistic Confidence
# 19        MMLU  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 20        MMLU  Llama-3.1-8B-Inst.      Token Probability
# 21        MMLU      Qwen3-8B-Inst.  Linguistic Confidence
# 22        MMLU      Qwen3-8B-Inst.   Semantic Uncertainty
# 23        MMLU      Qwen3-8B-Inst.      Token Probability
# 24  TruthfulQA         GPT-OSS-20B  Linguistic Confidence
# 25  TruthfulQA         GPT-OSS-20B   Semantic Uncertainty
# 26  TruthfulQA         GPT-OSS-20B      Token Probability
# 27  TruthfulQA    Mistral-7B-Inst.  Linguistic Confidence
# 28  TruthfulQA    Mistral-7B-Inst.   Semantic Uncertainty
# 29  TruthfulQA    Mistral-7B-Inst.      Token Probability
# 30  TruthfulQA  Llama-3.1-8B-Inst.  Linguistic Confidence
# 31  TruthfulQA  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 32  TruthfulQA  Llama-3.1-8B-Inst.      Token Probability
# 33  TruthfulQA      Qwen3-8B-Inst.  Linguistic Confidence
# 34  TruthfulQA      Qwen3-8B-Inst.   Semantic Uncertainty
# 35  TruthfulQA      Qwen3-8B-Inst.      Token Probability
#
#     Original Faithfulness Divergence  Calibrated Faithfulness Divergence  \
# 0                           3.274456                            0.615336
# 1                           3.274456                            0.158183
# 2                           3.274456                            0.554645
# 3                           2.628490                            0.598787
# 4                           2.628490                            0.445779
# 5                           2.628490                            0.569606
# 6                           2.156529                            0.698938
# 7                           2.156529                            1.681545
# 8                           2.156529                            0.643225
# 9                           2.606174                            0.759496
# 10                          2.606174                            0.398331
# 11                          2.606174                            0.602623
# 12                          2.837246                            0.679195
# 13                          2.837246                            0.630409
# 14                          2.837246                            0.713360
# 15                          1.716467                            0.597375
# 16                          1.716467                            1.450556
# 17                          1.716467                            0.516271
# 18                          1.379232                            0.560232
# 19                          1.379232                            0.370946
# 20                          1.379232                            0.556974
# 21                          1.175403                            0.591554
# 22                          1.175403                            2.213656
# 23                          1.175403                            0.544005
# 24                          2.560467                            0.786874
# 25                          2.560467                            0.489809
# 26                          2.560467                            0.679888
# 27                          2.150989                            0.705202
# 28                          2.150989                            0.138967
# 29                          2.150989                            0.636881
# 30                          2.100883                            0.570964
# 31                          2.100883                            1.304739
# 32                          2.100883                            0.488130
# 33                          2.566869                            0.574760
# 34                          2.566869                            0.196743
# 35                          2.566869                            0.573691
#
#     Original Generalised ECE  Calibrated Generalised ECE
# 0                   0.413939                    0.183773
# 1                   0.413939                    0.164925
# 2                   0.413939                    0.148793
# 3                   0.374258                    0.177958
# 4                   0.374258                    0.166311
# 5                   0.374258                    0.140034
# 6                   0.306621                    0.171670
# 7                   0.306621                    0.116859
# 8                   0.306621                    0.145206
# 9                   0.349312                    0.206443
# 10                  0.349312                    0.146888
# 11                  0.349312                    0.157035
# 12                  0.232663                    0.184864
# 13                  0.232663                    0.126476
# 14                  0.232663                    0.177385
# 15                  0.322834                    0.157012
# 16                  0.322834                    0.132306
# 17                  0.322834                    0.116897
# 18                  0.217603                    0.097874
# 19                  0.217603                    0.104283
# 20                  0.217603                    0.093419
# 21                  0.202932                    0.132324
# 22                  0.202932                    0.102226
# 23                  0.202932                    0.094567
# 24                  0.393695                    0.234657
# 25                  0.393695                    0.201807
# 26                  0.393695                    0.212361
# 27                  0.358210                    0.192855
# 28                  0.358210                    0.176889
# 29                  0.358210                    0.189241
# 30                  0.357889                    0.154329
# 31                  0.357889                    0.168059
# 32                  0.357889                    0.134539
# 33                  0.442049                    0.202347
# 34                  0.442049                    0.191303
# 35                  0.442049                    0.193793

# %%
prompt_type = "hedged_qa"
results_dir = f"/hdd/ivny/{prompt_type}_in_domain_calibration"

# list all leaf nodes in results_dir
leaf_dirs = []
for root, dirs, files in os.walk(results_dir):
    if not dirs:  # if there are no subdirectories, it's a leaf node
        leaf_dirs.append(root)

hedged_qa_all_records = []
for leaf_dir in leaf_dirs:
    _, _, _, _, dataset_name, _, model_name = leaf_dir.split("/")
    if os.path.exists(os.path.join(leaf_dir, "calibration_performance.csv")):
        csv_data = pd.read_csv(os.path.join(leaf_dir, "calibration_performance.csv"), index_col=0)
        csv_records = csv_data.transpose().to_dict("records")

        for record in csv_records:
            record["dataset"] = dataset_map.get(dataset_name, dataset_name)
            record["model"] = model_name_map.get(model_name, model_name)
            record["dataset_size"] = dataset_size.get(dataset_name, None)

        hedged_qa_all_records.extend(csv_records)
    else:
        print(model_name, dataset_name, "missing calibration_performance.csv")

# %%
hedged_qa_detailed_records = []

for _, record in pd.DataFrame(hedged_qa_all_records).iterrows():
    lc = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Linguistic Confidence",
      "Hedged QA Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Hedged QA Generalised ECE": record["original_lc_generalised_ECE"],
    }
    hedged_qa_detailed_records.append(lc)
    su = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Semantic Uncertainty",
      "Hedged QA Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Hedged QA Generalised ECE": record["original_lc_generalised_ECE"],
    }
    hedged_qa_detailed_records.append(su)
    tp = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Token Probability",
      "Hedged QA Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Hedged QA Generalised ECE": record["original_lc_generalised_ECE"],
    }
    hedged_qa_detailed_records.append(tp)

hedged_qa_df = pd.DataFrame(hedged_qa_detailed_records)
hedged_qa_df
# Out:
#        Dataset               Model              Estimator  \
# 0     SQuAD2.0         GPT-OSS-20B  Linguistic Confidence
# 1     SQuAD2.0         GPT-OSS-20B   Semantic Uncertainty
# 2     SQuAD2.0         GPT-OSS-20B      Token Probability
# 3     SQuAD2.0    Mistral-7B-Inst.  Linguistic Confidence
# 4     SQuAD2.0    Mistral-7B-Inst.   Semantic Uncertainty
# 5     SQuAD2.0    Mistral-7B-Inst.      Token Probability
# 6     SQuAD2.0  Llama-3.1-8B-Inst.  Linguistic Confidence
# 7     SQuAD2.0  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 8     SQuAD2.0  Llama-3.1-8B-Inst.      Token Probability
# 9     SQuAD2.0      Qwen3-8B-Inst.  Linguistic Confidence
# 10    SQuAD2.0      Qwen3-8B-Inst.   Semantic Uncertainty
# 11    SQuAD2.0      Qwen3-8B-Inst.      Token Probability
# 12        MMLU         GPT-OSS-20B  Linguistic Confidence
# 13        MMLU         GPT-OSS-20B   Semantic Uncertainty
# 14        MMLU         GPT-OSS-20B      Token Probability
# 15        MMLU    Mistral-7B-Inst.  Linguistic Confidence
# 16        MMLU    Mistral-7B-Inst.   Semantic Uncertainty
# 17        MMLU    Mistral-7B-Inst.      Token Probability
# 18        MMLU  Llama-3.1-8B-Inst.  Linguistic Confidence
# 19        MMLU  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 20        MMLU  Llama-3.1-8B-Inst.      Token Probability
# 21        MMLU      Qwen3-8B-Inst.  Linguistic Confidence
# 22        MMLU      Qwen3-8B-Inst.   Semantic Uncertainty
# 23        MMLU      Qwen3-8B-Inst.      Token Probability
# 24  TruthfulQA         GPT-OSS-20B  Linguistic Confidence
# 25  TruthfulQA         GPT-OSS-20B   Semantic Uncertainty
# 26  TruthfulQA         GPT-OSS-20B      Token Probability
# 27  TruthfulQA    Mistral-7B-Inst.  Linguistic Confidence
# 28  TruthfulQA    Mistral-7B-Inst.   Semantic Uncertainty
# 29  TruthfulQA    Mistral-7B-Inst.      Token Probability
# 30  TruthfulQA  Llama-3.1-8B-Inst.  Linguistic Confidence
# 31  TruthfulQA  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 32  TruthfulQA  Llama-3.1-8B-Inst.      Token Probability
# 33  TruthfulQA      Qwen3-8B-Inst.  Linguistic Confidence
# 34  TruthfulQA      Qwen3-8B-Inst.   Semantic Uncertainty
# 35  TruthfulQA      Qwen3-8B-Inst.      Token Probability
#
#     Hedged QA Faithfulness Divergence  Hedged QA Generalised ECE
# 0                            2.783112                   0.370964
# 1                            2.783112                   0.370964
# 2                            2.783112                   0.370964
# 3                            2.482342                   0.339802
# 4                            2.482342                   0.339802
# 5                            2.482342                   0.339802
# 6                            1.610278                   0.258079
# 7                            1.610278                   0.258079
# 8                            1.610278                   0.258079
# 9                            2.579218                   0.356738
# 10                           2.579218                   0.356738
# 11                           2.579218                   0.356738
# 12                           0.931332                   0.189246
# 13                           0.931332                   0.189246
# 14                           0.931332                   0.189246
# 15                           1.564972                   0.306592
# 16                           1.564972                   0.306592
# 17                           1.564972                   0.306592
# 18                           0.950787                   0.161772
# 19                           0.950787                   0.161772
# 20                           0.950787                   0.161772
# 21                           1.028537                   0.170888
# 22                           1.028537                   0.170888
# 23                           1.028537                   0.170888
# 24                           1.308207                   0.243223
# 25                           1.308207                   0.243223
# 26                           1.308207                   0.243223
# 27                           1.260249                   0.260077
# 28                           1.260249                   0.260077
# 29                           1.260249                   0.260077
# 30                           0.748948                   0.229578
# 31                           0.748948                   0.229578
# 32                           0.748948                   0.229578
# 33                           1.589165                   0.318300
# 34                           1.589165                   0.318300
# 35                           1.589165                   0.318300

# %%
combined_df = pd.merge(in_domain_df, hedged_qa_df, on=["Dataset", "Model", "Estimator"], how="inner")
combined_df.to_dict("records")
# Out:
# [{'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 3.2744557219444133,
#   'Calibrated Faithfulness Divergence': 0.6153363929110477,
#   'Original Generalised ECE': 0.4139394929046411,
#   'Calibrated Generalised ECE': 0.1837726267490453,
#   'Hedged QA Faithfulness Divergence': 2.783112326819216,
#   'Hedged QA Generalised ECE': 0.3709640833716229},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 3.2744557219444133,
#   'Calibrated Faithfulness Divergence': 0.1581832576312894,
#   'Original Generalised ECE': 0.4139394929046411,
#   'Calibrated Generalised ECE': 0.1649251611476303,
#   'Hedged QA Faithfulness Divergence': 2.783112326819216,
#   'Hedged QA Generalised ECE': 0.3709640833716229},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 3.2744557219444133,
#   'Calibrated Faithfulness Divergence': 0.5546451335094232,
#   'Original Generalised ECE': 0.4139394929046411,
#   'Calibrated Generalised ECE': 0.1487925010538465,
#   'Hedged QA Faithfulness Divergence': 2.783112326819216,
#   'Hedged QA Generalised ECE': 0.3709640833716229},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.6284899033393536,
#   'Calibrated Faithfulness Divergence': 0.5987872741860395,
#   'Original Generalised ECE': 0.3742576514368728,
#   'Calibrated Generalised ECE': 0.1779582216963053,
#   'Hedged QA Faithfulness Divergence': 2.482342384469024,
#   'Hedged QA Generalised ECE': 0.3398020081646093},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.6284899033393536,
#   'Calibrated Faithfulness Divergence': 0.4457785182261163,
#   'Original Generalised ECE': 0.3742576514368728,
#   'Calibrated Generalised ECE': 0.1663114323115887,
#   'Hedged QA Faithfulness Divergence': 2.482342384469024,
#   'Hedged QA Generalised ECE': 0.3398020081646093},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.6284899033393536,
#   'Calibrated Faithfulness Divergence': 0.5696062668734613,
#   'Original Generalised ECE': 0.3742576514368728,
#   'Calibrated Generalised ECE': 0.1400336583484663,
#   'Hedged QA Faithfulness Divergence': 2.482342384469024,
#   'Hedged QA Generalised ECE': 0.3398020081646093},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.1565287229953687,
#   'Calibrated Faithfulness Divergence': 0.6989384059006527,
#   'Original Generalised ECE': 0.3066212444965402,
#   'Calibrated Generalised ECE': 0.1716700316795567,
#   'Hedged QA Faithfulness Divergence': 1.610277646277343,
#   'Hedged QA Generalised ECE': 0.2580793718825191},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.1565287229953687,
#   'Calibrated Faithfulness Divergence': 1.6815447472800478,
#   'Original Generalised ECE': 0.3066212444965402,
#   'Calibrated Generalised ECE': 0.116859009658145,
#   'Hedged QA Faithfulness Divergence': 1.610277646277343,
#   'Hedged QA Generalised ECE': 0.2580793718825191},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.1565287229953687,
#   'Calibrated Faithfulness Divergence': 0.6432254191191972,
#   'Original Generalised ECE': 0.3066212444965402,
#   'Calibrated Generalised ECE': 0.1452058127782445,
#   'Hedged QA Faithfulness Divergence': 1.610277646277343,
#   'Hedged QA Generalised ECE': 0.2580793718825191},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.6061736075967468,
#   'Calibrated Faithfulness Divergence': 0.7594956953501886,
#   'Original Generalised ECE': 0.3493122003672106,
#   'Calibrated Generalised ECE': 0.2064431789204854,
#   'Hedged QA Faithfulness Divergence': 2.579217609423093,
#   'Hedged QA Generalised ECE': 0.3567380318580108},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.6061736075967468,
#   'Calibrated Faithfulness Divergence': 0.3983307973287541,
#   'Original Generalised ECE': 0.3493122003672106,
#   'Calibrated Generalised ECE': 0.1468875717922088,
#   'Hedged QA Faithfulness Divergence': 2.579217609423093,
#   'Hedged QA Generalised ECE': 0.3567380318580108},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.6061736075967468,
#   'Calibrated Faithfulness Divergence': 0.602622759877648,
#   'Original Generalised ECE': 0.3493122003672106,
#   'Calibrated Generalised ECE': 0.1570346166583064,
#   'Hedged QA Faithfulness Divergence': 2.579217609423093,
#   'Hedged QA Generalised ECE': 0.3567380318580108},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.837245803799079,
#   'Calibrated Faithfulness Divergence': 0.6791954991034155,
#   'Original Generalised ECE': 0.2326625386537092,
#   'Calibrated Generalised ECE': 0.1848640044363684,
#   'Hedged QA Faithfulness Divergence': 0.9313322715315844,
#   'Hedged QA Generalised ECE': 0.18924606836915},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.837245803799079,
#   'Calibrated Faithfulness Divergence': 0.6304089446093277,
#   'Original Generalised ECE': 0.2326625386537092,
#   'Calibrated Generalised ECE': 0.1264759011600576,
#   'Hedged QA Faithfulness Divergence': 0.9313322715315844,
#   'Hedged QA Generalised ECE': 0.18924606836915},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.837245803799079,
#   'Calibrated Faithfulness Divergence': 0.7133595904272296,
#   'Original Generalised ECE': 0.2326625386537092,
#   'Calibrated Generalised ECE': 0.1773853126791485,
#   'Hedged QA Faithfulness Divergence': 0.9313322715315844,
#   'Hedged QA Generalised ECE': 0.18924606836915},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.7164666492674017,
#   'Calibrated Faithfulness Divergence': 0.5973749627693844,
#   'Original Generalised ECE': 0.3228335395807479,
#   'Calibrated Generalised ECE': 0.1570115162323864,
#   'Hedged QA Faithfulness Divergence': 1.5649717277131725,
#   'Hedged QA Generalised ECE': 0.3065915768845367},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.7164666492674017,
#   'Calibrated Faithfulness Divergence': 1.4505557351432938,
#   'Original Generalised ECE': 0.3228335395807479,
#   'Calibrated Generalised ECE': 0.1323060602488955,
#   'Hedged QA Faithfulness Divergence': 1.5649717277131725,
#   'Hedged QA Generalised ECE': 0.3065915768845367},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.7164666492674017,
#   'Calibrated Faithfulness Divergence': 0.5162709584412338,
#   'Original Generalised ECE': 0.3228335395807479,
#   'Calibrated Generalised ECE': 0.1168969828623721,
#   'Hedged QA Faithfulness Divergence': 1.5649717277131725,
#   'Hedged QA Generalised ECE': 0.3065915768845367},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.3792323485573814,
#   'Calibrated Faithfulness Divergence': 0.5602315489733091,
#   'Original Generalised ECE': 0.217603108407946,
#   'Calibrated Generalised ECE': 0.0978736251769752,
#   'Hedged QA Faithfulness Divergence': 0.950786554108674,
#   'Hedged QA Generalised ECE': 0.1617716401030677},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.3792323485573814,
#   'Calibrated Faithfulness Divergence': 0.3709455611996127,
#   'Original Generalised ECE': 0.217603108407946,
#   'Calibrated Generalised ECE': 0.1042834764500688,
#   'Hedged QA Faithfulness Divergence': 0.950786554108674,
#   'Hedged QA Generalised ECE': 0.1617716401030677},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.3792323485573814,
#   'Calibrated Faithfulness Divergence': 0.5569739690608253,
#   'Original Generalised ECE': 0.217603108407946,
#   'Calibrated Generalised ECE': 0.0934194057217185,
#   'Hedged QA Faithfulness Divergence': 0.950786554108674,
#   'Hedged QA Generalised ECE': 0.1617716401030677},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.175402607207917,
#   'Calibrated Faithfulness Divergence': 0.5915535800173589,
#   'Original Generalised ECE': 0.2029324319809513,
#   'Calibrated Generalised ECE': 0.1323235342505481,
#   'Hedged QA Faithfulness Divergence': 1.028537193154343,
#   'Hedged QA Generalised ECE': 0.1708880894896547},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.175402607207917,
#   'Calibrated Faithfulness Divergence': 2.213656007271652,
#   'Original Generalised ECE': 0.2029324319809513,
#   'Calibrated Generalised ECE': 0.1022257961194337,
#   'Hedged QA Faithfulness Divergence': 1.028537193154343,
#   'Hedged QA Generalised ECE': 0.1708880894896547},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.175402607207917,
#   'Calibrated Faithfulness Divergence': 0.544004832563747,
#   'Original Generalised ECE': 0.2029324319809513,
#   'Calibrated Generalised ECE': 0.0945669126959059,
#   'Hedged QA Faithfulness Divergence': 1.028537193154343,
#   'Hedged QA Generalised ECE': 0.1708880894896547},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.5604670593126566,
#   'Calibrated Faithfulness Divergence': 0.7868736456969415,
#   'Original Generalised ECE': 0.3936952857586958,
#   'Calibrated Generalised ECE': 0.2346571260942265,
#   'Hedged QA Faithfulness Divergence': 1.3082074742399843,
#   'Hedged QA Generalised ECE': 0.2432229946228962},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.5604670593126566,
#   'Calibrated Faithfulness Divergence': 0.4898093509040927,
#   'Original Generalised ECE': 0.3936952857586958,
#   'Calibrated Generalised ECE': 0.2018065896326342,
#   'Hedged QA Faithfulness Divergence': 1.3082074742399843,
#   'Hedged QA Generalised ECE': 0.2432229946228962},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.5604670593126566,
#   'Calibrated Faithfulness Divergence': 0.6798878155914033,
#   'Original Generalised ECE': 0.3936952857586958,
#   'Calibrated Generalised ECE': 0.2123611219221109,
#   'Hedged QA Faithfulness Divergence': 1.3082074742399843,
#   'Hedged QA Generalised ECE': 0.2432229946228962},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.1509891418321483,
#   'Calibrated Faithfulness Divergence': 0.7052021040828227,
#   'Original Generalised ECE': 0.3582103820285571,
#   'Calibrated Generalised ECE': 0.1928550816955807,
#   'Hedged QA Faithfulness Divergence': 1.2602489864472812,
#   'Hedged QA Generalised ECE': 0.260076677104771},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.1509891418321483,
#   'Calibrated Faithfulness Divergence': 0.1389674888777404,
#   'Original Generalised ECE': 0.3582103820285571,
#   'Calibrated Generalised ECE': 0.1768892755005966,
#   'Hedged QA Faithfulness Divergence': 1.2602489864472812,
#   'Hedged QA Generalised ECE': 0.260076677104771},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.1509891418321483,
#   'Calibrated Faithfulness Divergence': 0.6368806265772041,
#   'Original Generalised ECE': 0.3582103820285571,
#   'Calibrated Generalised ECE': 0.1892414307437963,
#   'Hedged QA Faithfulness Divergence': 1.2602489864472812,
#   'Hedged QA Generalised ECE': 0.260076677104771},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.100882829979433,
#   'Calibrated Faithfulness Divergence': 0.5709637588113987,
#   'Original Generalised ECE': 0.3578893056016395,
#   'Calibrated Generalised ECE': 0.1543285948191795,
#   'Hedged QA Faithfulness Divergence': 0.748948156055647,
#   'Hedged QA Generalised ECE': 0.2295781296509278},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.100882829979433,
#   'Calibrated Faithfulness Divergence': 1.30473863254142,
#   'Original Generalised ECE': 0.3578893056016395,
#   'Calibrated Generalised ECE': 0.1680591848093483,
#   'Hedged QA Faithfulness Divergence': 0.748948156055647,
#   'Hedged QA Generalised ECE': 0.2295781296509278},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.100882829979433,
#   'Calibrated Faithfulness Divergence': 0.4881299310095239,
#   'Original Generalised ECE': 0.3578893056016395,
#   'Calibrated Generalised ECE': 0.1345387751948367,
#   'Hedged QA Faithfulness Divergence': 0.748948156055647,
#   'Hedged QA Generalised ECE': 0.2295781296509278},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.5668687390576914,
#   'Calibrated Faithfulness Divergence': 0.574759566278733,
#   'Original Generalised ECE': 0.4420487516163188,
#   'Calibrated Generalised ECE': 0.2023472258446318,
#   'Hedged QA Faithfulness Divergence': 1.5891645824014775,
#   'Hedged QA Generalised ECE': 0.3182997020772422},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.5668687390576914,
#   'Calibrated Faithfulness Divergence': 0.1967425391838083,
#   'Original Generalised ECE': 0.4420487516163188,
#   'Calibrated Generalised ECE': 0.1913030220242001,
#   'Hedged QA Faithfulness Divergence': 1.5891645824014775,
#   'Hedged QA Generalised ECE': 0.3182997020772422},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.5668687390576914,
#   'Calibrated Faithfulness Divergence': 0.5736913347476824,
#   'Original Generalised ECE': 0.4420487516163188,
#   'Calibrated Generalised ECE': 0.1937933549697698,
#   'Hedged QA Faithfulness Divergence': 1.5891645824014775,
#   'Hedged QA Generalised ECE': 0.3182997020772422}]

# %%
from collections import defaultdict


ESTIMATOR_ORDER = ["Linguistic Confidence", "Semantic Uncertainty", "Token Probability"]

ESTIMATOR_LABELS = {
    "Linguistic Confidence": "Linguistic Conf.",
    "Semantic Uncertainty":  "Semantic Unc.",
    "Token Probability":     "Token Prob.",
}


def _fmt(value: float, decimals: int = 3) -> str:
    return f"{value:.{decimals}f}"


def _arrow(orig: float, calib: float, decimals: int = 3) -> str:
    return f"${_fmt(orig, decimals)} \\to {_fmt(calib, decimals)}$"


def generate_latex_table(
    data: list[dict],
    caption: str = "Calibration results across datasets, models, and estimators. Lower is better for all metrics.",
    label: str = "tab:results",
    decimals: int = 3,
    dataset_order: list[str] | None = None,
    model_order: list[str] | None = None,
) -> str:
    """
    Convert a list of result dicts into a LaTeX table string.

    Args:
        data:          List of result dicts (see module docstring for expected keys).
        caption:       Table caption.
        label:         LaTeX label for \\ref{}.
        decimals:      Decimal places for all numeric values.
        dataset_order: Optional explicit ordering of datasets.
                       Defaults to insertion order found in data.
        model_order:   Optional explicit ordering of models within each dataset.
                       Defaults to insertion order found in data.

    Returns:
        A self-contained LaTeX string (table* environment).
        Required packages: booktabs, multirow, makecell.
    """
    # ── 1. Index data: dataset -> model -> estimator -> row ──────────────────
    index: dict[str, dict[str, dict[str, dict]]] = defaultdict(lambda: defaultdict(dict))
    seen_datasets: list[str] = []
    seen_models: dict[str, list[str]] = defaultdict(list)

    for row in data:
        ds   = row["Dataset"]
        mdl  = row["Model"]
        est  = row["Estimator"]

        if ds not in seen_datasets:
            seen_datasets.append(ds)
        if mdl not in seen_models[ds]:
            seen_models[ds].append(mdl)

        index[ds][mdl][est] = row

    datasets = dataset_order if dataset_order is not None else seen_datasets
    
    def get_models(ds):
        if model_order is not None:
            return [m for m in model_order if m in index[ds]]
        return seen_models[ds]

    # ── 2. Build header ───────────────────────────────────────────────────────
    header = r"""\begin{table*}[ht]
\centering
\caption{""" + caption + r"""}
\label{""" + label + r"""}
\resizebox{\textwidth}{!}{%
\begin{tabular}{llllcccc}
\toprule
\multirow{3}{*}{Dataset}
  & \multirow{3}{*}{Model}
  & \multirow{3}{*}{Estimator}
  & \multicolumn{2}{c}{\textbf{In-Domain Calibration}}
  & \multicolumn{2}{c}{\textbf{Hedged QA}} \\
\cmidrule(lr){4-5} \cmidrule(lr){6-7}
  & & & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Calib.)}
       & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Calib.)}
       & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Hedged)}
       & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Hedged)} \\
\midrule"""

    # ── 3. Build body rows ────────────────────────────────────────────────────
    body_lines: list[str] = []

    for ds_idx, ds in enumerate(datasets):
        models = get_models(ds)
        n_ds_rows = len(models) * len(ESTIMATOR_ORDER)

        ds_cell = f"\\multirow{{{n_ds_rows}}}{{*}}{{{ds}}}"
        first_ds_row = True

        for mdl_idx, mdl in enumerate(models):
            estimators = ESTIMATOR_ORDER

            mdl_cell = f"\\multirow{{{len(estimators)}}}{{*}}{{{mdl}}}"
            first_mdl_row = True

            for est_idx, est in enumerate(estimators):
                row = index[ds][mdl].get(est)
                if row is None:
                    continue

                # In-domain calibration columns (vary per estimator)
                fd_cell  = _arrow(row["Original Faithfulness Divergence"],
                                  row["Calibrated Faithfulness Divergence"], decimals)
                ece_cell = _arrow(row["Original Generalised ECE"],
                                  row["Calibrated Generalised ECE"], decimals)

                # Hedged QA columns (same for all estimators of this model/dataset)
                if first_mdl_row:
                    hfd_cell = (f"\\multirow{{{len(estimators)}}}{{*}}{{"
                                + _arrow(row["Original Faithfulness Divergence"],
                                         row["Hedged QA Faithfulness Divergence"], decimals)
                                + "}")
                    hece_cell = (f"\\multirow{{{len(estimators)}}}{{*}}{{"
                                 + _arrow(row["Original Generalised ECE"],
                                          row["Hedged QA Generalised ECE"], decimals)
                                 + "}")
                else:
                    hfd_cell  = ""
                    hece_cell = ""

                est_label = ESTIMATOR_LABELS.get(est, est)

                # Assemble leading cells
                if first_ds_row and first_mdl_row:
                    leading = f" {ds_cell} & {mdl_cell}"
                elif first_mdl_row:
                    leading = f" & {mdl_cell}"
                else:
                    leading = f" &"

                line = (f"{leading} & {est_label}"
                        f" & {fd_cell} & {ece_cell}"
                        f" & {hfd_cell} & {hece_cell} \\\\")

                body_lines.append(line)
                first_ds_row   = False
                first_mdl_row  = False

            # Separator between models (not after the last model in a dataset)
            if mdl_idx < len(models) - 1:
                body_lines.append(r"\cmidrule(l){2-7}")

        # Separator between datasets (not after the last one)
        if ds_idx < len(datasets) - 1:
            body_lines.append(r"\midrule")

    # ── 4. Footer ─────────────────────────────────────────────────────────────
    footer = r"""\bottomrule
\end{tabular}%
}
\end{table*}"""

    return "\n".join([header, *body_lines, footer])


print(generate_latex_table(combined_df.to_dict("records"), caption="Sample table.", label="tab:sample"))
# Out:
# \begin{table*}[ht]
# \centering
# \caption{Sample table.}
# \label{tab:sample}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{llllcccc}
# \toprule
# \multirow{3}{*}{Dataset}
#   & \multirow{3}{*}{Model}
#   & \multirow{3}{*}{Estimator}
#   & \multicolumn{2}{c}{\textbf{In-Domain Calibration}}
#   & \multicolumn{2}{c}{\textbf{Hedged QA}} \\
# \cmidrule(lr){4-5} \cmidrule(lr){6-7}
#   & & & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Calib.)}
#        & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Calib.)}
#        & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Hedged)}
#        & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Hedged)} \\
# \midrule
#  \multirow{12}{*}{SQuAD2.0} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $3.274 \to 0.615$ & $0.414 \to 0.184$ & \multirow{3}{*}{$3.274 \to 2.783$} & \multirow{3}{*}{$0.414 \to 0.371$} \\
#  & & Semantic Unc. & $3.274 \to 0.158$ & $0.414 \to 0.165$ &  &  \\
#  & & Token Prob. & $3.274 \to 0.555$ & $0.414 \to 0.149$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $2.628 \to 0.599$ & $0.374 \to 0.178$ & \multirow{3}{*}{$2.628 \to 2.482$} & \multirow{3}{*}{$0.374 \to 0.340$} \\
#  & & Semantic Unc. & $2.628 \to 0.446$ & $0.374 \to 0.166$ &  &  \\
#  & & Token Prob. & $2.628 \to 0.570$ & $0.374 \to 0.140$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $2.157 \to 0.699$ & $0.307 \to 0.172$ & \multirow{3}{*}{$2.157 \to 1.610$} & \multirow{3}{*}{$0.307 \to 0.258$} \\
#  & & Semantic Unc. & $2.157 \to 1.682$ & $0.307 \to 0.117$ &  &  \\
#  & & Token Prob. & $2.157 \to 0.643$ & $0.307 \to 0.145$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $2.606 \to 0.759$ & $0.349 \to 0.206$ & \multirow{3}{*}{$2.606 \to 2.579$} & \multirow{3}{*}{$0.349 \to 0.357$} \\
#  & & Semantic Unc. & $2.606 \to 0.398$ & $0.349 \to 0.147$ &  &  \\
#  & & Token Prob. & $2.606 \to 0.603$ & $0.349 \to 0.157$ &  &  \\
# \midrule
#  \multirow{12}{*}{MMLU} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $2.837 \to 0.679$ & $0.233 \to 0.185$ & \multirow{3}{*}{$2.837 \to 0.931$} & \multirow{3}{*}{$0.233 \to 0.189$} \\
#  & & Semantic Unc. & $2.837 \to 0.630$ & $0.233 \to 0.126$ &  &  \\
#  & & Token Prob. & $2.837 \to 0.713$ & $0.233 \to 0.177$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $1.716 \to 0.597$ & $0.323 \to 0.157$ & \multirow{3}{*}{$1.716 \to 1.565$} & \multirow{3}{*}{$0.323 \to 0.307$} \\
#  & & Semantic Unc. & $1.716 \to 1.451$ & $0.323 \to 0.132$ &  &  \\
#  & & Token Prob. & $1.716 \to 0.516$ & $0.323 \to 0.117$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $1.379 \to 0.560$ & $0.218 \to 0.098$ & \multirow{3}{*}{$1.379 \to 0.951$} & \multirow{3}{*}{$0.218 \to 0.162$} \\
#  & & Semantic Unc. & $1.379 \to 0.371$ & $0.218 \to 0.104$ &  &  \\
#  & & Token Prob. & $1.379 \to 0.557$ & $0.218 \to 0.093$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $1.175 \to 0.592$ & $0.203 \to 0.132$ & \multirow{3}{*}{$1.175 \to 1.029$} & \multirow{3}{*}{$0.203 \to 0.171$} \\
#  & & Semantic Unc. & $1.175 \to 2.214$ & $0.203 \to 0.102$ &  &  \\
#  & & Token Prob. & $1.175 \to 0.544$ & $0.203 \to 0.095$ &  &  \\
# \midrule
#  \multirow{12}{*}{TruthfulQA} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $2.560 \to 0.787$ & $0.394 \to 0.235$ & \multirow{3}{*}{$2.560 \to 1.308$} & \multirow{3}{*}{$0.394 \to 0.243$} \\
#  & & Semantic Unc. & $2.560 \to 0.490$ & $0.394 \to 0.202$ &  &  \\
#  & & Token Prob. & $2.560 \to 0.680$ & $0.394 \to 0.212$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $2.151 \to 0.705$ & $0.358 \to 0.193$ & \multirow{3}{*}{$2.151 \to 1.260$} & \multirow{3}{*}{$0.358 \to 0.260$} \\
#  & & Semantic Unc. & $2.151 \to 0.139$ & $0.358 \to 0.177$ &  &  \\
#  & & Token Prob. & $2.151 \to 0.637$ & $0.358 \to 0.189$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $2.101 \to 0.571$ & $0.358 \to 0.154$ & \multirow{3}{*}{$2.101 \to 0.749$} & \multirow{3}{*}{$0.358 \to 0.230$} \\
#  & & Semantic Unc. & $2.101 \to 1.305$ & $0.358 \to 0.168$ &  &  \\
#  & & Token Prob. & $2.101 \to 0.488$ & $0.358 \to 0.135$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $2.567 \to 0.575$ & $0.442 \to 0.202$ & \multirow{3}{*}{$2.567 \to 1.589$} & \multirow{3}{*}{$0.442 \to 0.318$} \\
#  & & Semantic Unc. & $2.567 \to 0.197$ & $0.442 \to 0.191$ &  &  \\
#  & & Token Prob. & $2.567 \to 0.574$ & $0.442 \to 0.194$ &  &  \\
# \bottomrule
# \end{tabular}%
# }
# \end{table*}
