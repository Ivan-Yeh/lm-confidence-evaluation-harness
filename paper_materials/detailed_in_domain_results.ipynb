# %%
import os
import pandas as pd
import numpy as np

# %%
methods_names = {
    "dist_linguistic_confidence": "Dist. Ling. Conf.",
    "dist_semantic_uncertainty": "Dist. Semantic Unc.",
    "dist_lnll": "Dist. Token Prob"
}

dataset_size = {
    "mmlu": 116000,
    "squadv2": 130000,
    "truthful_qa": 817
}

dataset_map = {
    "mmlu": "MMLU",
    "squadv2": "SQuAD2.0",
    "truthful_qa": "TruthfulQA"
}

model_name_map = {
    "Llama-3.1-8B-Instruct": "Llama-3.1-8B-Inst.",
    "Meta-Llama-3-8B-Instruct": "Llama-3-8B-Inst.",
    "Qwen2.5-7B-Instruct": "Qwen2.5-7B-Inst.",
    "Qwen3-8B": "Qwen3-8B-Inst.",
    "Mistral-7B-Instruct-v0.3": "Mistral-7B-Inst.",
    "gpt-oss-20b": "GPT-OSS-20B",
}

# %%
prompt_type = "direct_qa"
results_dir = f"/hdd/ivny/{prompt_type}_in_domain_calibration"

# list all leaf nodes in results_dir
leaf_dirs = []
for root, dirs, files in os.walk(results_dir):
    if not dirs:  # if there are no subdirectories, it's a leaf node
        leaf_dirs.append(root)

all_records = []
for leaf_dir in leaf_dirs:
    _, _, _, _, dataset_name, _, model_name = leaf_dir.split("/")
    if os.path.exists(os.path.join(leaf_dir, "calibration_performance.csv")):
        csv_data = pd.read_csv(os.path.join(leaf_dir, "calibration_performance.csv"), index_col=0)
        csv_records = csv_data.transpose().to_dict("records")

        for record in csv_records:
            record["dataset"] = dataset_map.get(dataset_name, dataset_name)
            record["model"] = model_name_map.get(model_name, model_name)
            record["dataset_size"] = dataset_size.get(dataset_name, None)

        all_records.extend(csv_records)
    else:
        print(model_name, dataset_name, "missing calibration_performance.csv")

# %%
full_df = pd.DataFrame(all_records)
full_df
# Out:
#     original_lc_generalised_ECE  original_lc_faithfulness_divergence  \
# 0                      0.413961                             3.273352
# 1                      0.374306                             2.627479
# 2                      0.306455                             2.154985
# 3                      0.349454                             2.604911
# 4                      0.232887                             2.836707
# 5                      0.323076                             1.715968
# 6                      0.217563                             1.377779
# 7                      0.202914                             1.174774
# 8                      0.393611                             2.558804
# 9                      0.358615                             2.149524
# 10                     0.358080                             2.098327
# 11                     0.441578                             2.564410
#
#     original_lc_ece_mean  original_lc_dAUROC  original_lc_auroc_mean  \
# 0               0.395699             0.51540                0.503842
# 1               0.362216             0.51750                0.524924
# 2               0.296183             0.54510                0.566522
# 3               0.340447             0.51220                0.518984
# 4               0.180036             0.49795                0.489187
# 5               0.261834             0.47130                0.462672
# 6               0.188021             0.58230                0.605029
# 7               0.142476             0.51880                0.539133
# 8               0.384898             0.57480                0.612122
# 9               0.349199             0.55950                0.585261
# 10              0.353123             0.56200                0.594945
# 11              0.441812             0.57280                0.626814
#
#     original_tp_generalised_ECE  original_tp_faithfulness_divergence  \
# 0                      0.211723                             0.708584
# 1                      0.277460                             2.810419
# 2                      0.132830                             0.631105
# 3                      0.388906                            45.867481
# 4                      0.149964                             2.083934
# 5                      0.312567                            88.616662
# 6                      0.155289                             0.432204
# 7                      0.272201                           280.166764
# 8                      0.100675                             0.530418
# 9                      0.146061                             0.667714
# 10                     0.050693                             0.472168
# 11                     0.427582                            25.750811
#
#     original_tp_ece_mean  original_tp_dAUROC  original_tp_auroc_mean  ...  \
# 0               0.209470             0.61970                0.671092  ...
# 1               0.276868             0.67110                0.694870  ...
# 2               0.113532             0.69050                0.733780  ...
# 3               0.388661             0.66235                0.688362  ...
# 4               0.087214             0.50230                0.499500  ...
# 5               0.306756             0.60060                0.624988  ...
# 6               0.130197             0.61140                0.698521  ...
# 7               0.269200             0.59430                0.570269  ...
# 8               0.091167             0.58810                0.626063  ...
# 9               0.116989             0.52380                0.519139  ...
# 10              0.068014             0.64330                0.713940  ...
# 11              0.427671             0.58040                0.611500  ...
#
#     calibrated_tp_rewritten_lc_dAUROC  calibrated_tp_rewritten_lc_auroc_mean  \
# 0                              0.5608                               0.604101
# 1                              0.5829                               0.625023
# 2                              0.6316                               0.669447
# 3                              0.5393                               0.555123
# 4                              0.5245                               0.518189
# 5                              0.5558                               0.582352
# 6                              0.6330                               0.666601
# 7                              0.5182                               0.546945
# 8                              0.5930                               0.646440
# 9                              0.5152                               0.539943
# 10                             0.5801                               0.617572
# 11                             0.5533                               0.588525
#
#     calibrated_su_rewritten_lc_generalised_ECE  \
# 0                                     0.164915
# 1                                     0.166334
# 2                                     0.116909
# 3                                     0.146723
# 4                                     0.126385
# 5                                     0.132085
# 6                                     0.104335
# 7                                     0.102093
# 8                                     0.201327
# 9                                     0.177002
# 10                                    0.167127
# 11                                    0.191608
#
#     calibrated_su_rewritten_lc_faithfulness_divergence  \
# 0                                            0.643274
# 1                                            0.668390
# 2                                            0.617548
# 3                                            0.640668
# 4                                            0.475499
# 5                                            0.502037
# 6                                            0.621727
# 7                                            0.592721
# 8                                            0.651611
# 9                                            0.617369
# 10                                           0.570702
# 11                                           0.590264
#
#     calibrated_su_rewritten_lc_ece_mean  calibrated_su_rewritten_lc_dAUROC  \
# 0                              0.155648                             0.5994
# 1                              0.141688                             0.5408
# 2                              0.100706                             0.5745
# 3                              0.116548                             0.5527
# 4                              0.053905                             0.6433
# 5                              0.072146                             0.5315
# 6                              0.085277                             0.6750
# 7                              0.044590                             0.5609
# 8                              0.196160                             0.6150
# 9                              0.176902                             0.6129
# 10                             0.127107                             0.5372
# 11                             0.180934                             0.5698
#
#     calibrated_su_rewritten_lc_auroc_mean     dataset               model  \
# 0                                0.639329    SQuAD2.0         GPT-OSS-20B
# 1                                0.566120    SQuAD2.0    Mistral-7B-Inst.
# 2                                0.604327    SQuAD2.0  Llama-3.1-8B-Inst.
# 3                                0.571994    SQuAD2.0      Qwen3-8B-Inst.
# 4                                0.666217        MMLU         GPT-OSS-20B
# 5                                0.555023        MMLU    Mistral-7B-Inst.
# 6                                0.716231        MMLU  Llama-3.1-8B-Inst.
# 7                                0.587880        MMLU      Qwen3-8B-Inst.
# 8                                0.652594  TruthfulQA         GPT-OSS-20B
# 9                                0.656544  TruthfulQA    Mistral-7B-Inst.
# 10                               0.553557  TruthfulQA  Llama-3.1-8B-Inst.
# 11                               0.614632  TruthfulQA      Qwen3-8B-Inst.
#
#     dataset_size
# 0         130000
# 1         130000
# 2         130000
# 3         130000
# 4         116000
# 5         116000
# 6         116000
# 7         116000
# 8            817
# 9            817
# 10           817
# 11           817
#
# [12 rows x 48 columns]

# %%
full_df.columns
# Out:
# Index(['original_lc_generalised_ECE', 'original_lc_faithfulness_divergence',
#        'original_lc_ece_mean', 'original_lc_dAUROC', 'original_lc_auroc_mean',
#        'original_tp_generalised_ECE', 'original_tp_faithfulness_divergence',
#        'original_tp_ece_mean', 'original_tp_dAUROC', 'original_tp_auroc_mean',
#        'original_su_generalised_ECE', 'original_su_faithfulness_divergence',
#        'original_su_ece_mean', 'original_su_dAUROC', 'original_su_auroc_mean',
#        'calibrated_lc_generalised_ECE',
#        'calibrated_lc_faithfulness_divergence', 'calibrated_lc_ece_mean',
#        'calibrated_lc_dAUROC', 'calibrated_lc_auroc_mean',
#        'calibrated_tp_generalised_ECE',
#        'calibrated_tp_faithfulness_divergence', 'calibrated_tp_ece_mean',
#        'calibrated_tp_dAUROC', 'calibrated_tp_auroc_mean',
#        'calibrated_su_generalised_ECE',
#        'calibrated_su_faithfulness_divergence', 'calibrated_su_ece_mean',
#        'calibrated_su_dAUROC', 'calibrated_su_auroc_mean',
#        'calibrated_lc_rewritten_lc_generalised_ECE',
#        'calibrated_lc_rewritten_lc_faithfulness_divergence',
#        'calibrated_lc_rewritten_lc_ece_mean',
#        'calibrated_lc_rewritten_lc_dAUROC',
#        'calibrated_lc_rewritten_lc_auroc_mean',
#        'calibrated_tp_rewritten_lc_generalised_ECE',
#        'calibrated_tp_rewritten_lc_faithfulness_divergence',
#        'calibrated_tp_rewritten_lc_ece_mean',
#        'calibrated_tp_rewritten_lc_dAUROC',
#        'calibrated_tp_rewritten_lc_auroc_mean',
#        'calibrated_su_rewritten_lc_generalised_ECE',
#        'calibrated_su_rewritten_lc_faithfulness_divergence',
#        'calibrated_su_rewritten_lc_ece_mean',
#        'calibrated_su_rewritten_lc_dAUROC',
#        'calibrated_su_rewritten_lc_auroc_mean', 'dataset', 'model',
#        'dataset_size'],
#       dtype='str')

# %%
in_domain_detailed_records = []

for _, record in full_df.iterrows():
    lc = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Linguistic Confidence",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_lc_rewritten_lc_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_lc_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(lc)
    su = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Semantic Uncertainty",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_su_rewritten_lc_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_su_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(su)
    tp = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Token Probability",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_tp_rewritten_lc_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_tp_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(tp)

# %%
in_domain_df = pd.DataFrame(in_domain_detailed_records)
in_domain_df
# Out:
#        Dataset               Model              Estimator  \
# 0     SQuAD2.0         GPT-OSS-20B  Linguistic Confidence
# 1     SQuAD2.0         GPT-OSS-20B   Semantic Uncertainty
# 2     SQuAD2.0         GPT-OSS-20B      Token Probability
# 3     SQuAD2.0    Mistral-7B-Inst.  Linguistic Confidence
# 4     SQuAD2.0    Mistral-7B-Inst.   Semantic Uncertainty
# 5     SQuAD2.0    Mistral-7B-Inst.      Token Probability
# 6     SQuAD2.0  Llama-3.1-8B-Inst.  Linguistic Confidence
# 7     SQuAD2.0  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 8     SQuAD2.0  Llama-3.1-8B-Inst.      Token Probability
# 9     SQuAD2.0      Qwen3-8B-Inst.  Linguistic Confidence
# 10    SQuAD2.0      Qwen3-8B-Inst.   Semantic Uncertainty
# 11    SQuAD2.0      Qwen3-8B-Inst.      Token Probability
# 12        MMLU         GPT-OSS-20B  Linguistic Confidence
# 13        MMLU         GPT-OSS-20B   Semantic Uncertainty
# 14        MMLU         GPT-OSS-20B      Token Probability
# 15        MMLU    Mistral-7B-Inst.  Linguistic Confidence
# 16        MMLU    Mistral-7B-Inst.   Semantic Uncertainty
# 17        MMLU    Mistral-7B-Inst.      Token Probability
# 18        MMLU  Llama-3.1-8B-Inst.  Linguistic Confidence
# 19        MMLU  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 20        MMLU  Llama-3.1-8B-Inst.      Token Probability
# 21        MMLU      Qwen3-8B-Inst.  Linguistic Confidence
# 22        MMLU      Qwen3-8B-Inst.   Semantic Uncertainty
# 23        MMLU      Qwen3-8B-Inst.      Token Probability
# 24  TruthfulQA         GPT-OSS-20B  Linguistic Confidence
# 25  TruthfulQA         GPT-OSS-20B   Semantic Uncertainty
# 26  TruthfulQA         GPT-OSS-20B      Token Probability
# 27  TruthfulQA    Mistral-7B-Inst.  Linguistic Confidence
# 28  TruthfulQA    Mistral-7B-Inst.   Semantic Uncertainty
# 29  TruthfulQA    Mistral-7B-Inst.      Token Probability
# 30  TruthfulQA  Llama-3.1-8B-Inst.  Linguistic Confidence
# 31  TruthfulQA  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 32  TruthfulQA  Llama-3.1-8B-Inst.      Token Probability
# 33  TruthfulQA      Qwen3-8B-Inst.  Linguistic Confidence
# 34  TruthfulQA      Qwen3-8B-Inst.   Semantic Uncertainty
# 35  TruthfulQA      Qwen3-8B-Inst.      Token Probability
#
#     Original Faithfulness Divergence  Calibrated Faithfulness Divergence  \
# 0                           3.273352                            0.615336
# 1                           3.273352                            0.643274
# 2                           3.273352                            0.554645
# 3                           2.627479                            0.598787
# 4                           2.627479                            0.668390
# 5                           2.627479                            0.569606
# 6                           2.154985                            0.698938
# 7                           2.154985                            0.617548
# 8                           2.154985                            0.643225
# 9                           2.604911                            0.759496
# 10                          2.604911                            0.640668
# 11                          2.604911                            0.602623
# 12                          2.836707                            0.679195
# 13                          2.836707                            0.475499
# 14                          2.836707                            0.713360
# 15                          1.715968                            0.597375
# 16                          1.715968                            0.502037
# 17                          1.715968                            0.516271
# 18                          1.377779                            0.560232
# 19                          1.377779                            0.621727
# 20                          1.377779                            0.556974
# 21                          1.174774                            0.591554
# 22                          1.174774                            0.592721
# 23                          1.174774                            0.544005
# 24                          2.558804                            0.786874
# 25                          2.558804                            0.651611
# 26                          2.558804                            0.679888
# 27                          2.149524                            0.705202
# 28                          2.149524                            0.617369
# 29                          2.149524                            0.636881
# 30                          2.098327                            0.570964
# 31                          2.098327                            0.570702
# 32                          2.098327                            0.488130
# 33                          2.564410                            0.574760
# 34                          2.564410                            0.590264
# 35                          2.564410                            0.573691
#
#     Original Generalised ECE  Calibrated Generalised ECE
# 0                   0.413961                    0.183936
# 1                   0.413961                    0.164915
# 2                   0.413961                    0.148827
# 3                   0.374306                    0.178055
# 4                   0.374306                    0.166334
# 5                   0.374306                    0.140093
# 6                   0.306455                    0.171446
# 7                   0.306455                    0.116909
# 8                   0.306455                    0.145184
# 9                   0.349454                    0.206343
# 10                  0.349454                    0.146723
# 11                  0.349454                    0.157179
# 12                  0.232887                    0.184909
# 13                  0.232887                    0.126385
# 14                  0.232887                    0.177222
# 15                  0.323076                    0.156901
# 16                  0.323076                    0.132085
# 17                  0.323076                    0.116701
# 18                  0.217563                    0.097743
# 19                  0.217563                    0.104335
# 20                  0.217563                    0.093043
# 21                  0.202914                    0.132440
# 22                  0.202914                    0.102093
# 23                  0.202914                    0.094392
# 24                  0.393611                    0.234789
# 25                  0.393611                    0.201327
# 26                  0.393611                    0.212190
# 27                  0.358615                    0.192625
# 28                  0.358615                    0.177002
# 29                  0.358615                    0.189857
# 30                  0.358080                    0.154869
# 31                  0.358080                    0.167127
# 32                  0.358080                    0.135428
# 33                  0.441578                    0.203662
# 34                  0.441578                    0.191608
# 35                  0.441578                    0.193844

# %%
prompt_type = "hedged_qa"
results_dir = f"/hdd/ivny/{prompt_type}_in_domain_calibration"

# list all leaf nodes in results_dir
leaf_dirs = []
for root, dirs, files in os.walk(results_dir):
    if not dirs:  # if there are no subdirectories, it's a leaf node
        leaf_dirs.append(root)

hedged_qa_all_records = []
for leaf_dir in leaf_dirs:
    _, _, _, _, dataset_name, _, model_name = leaf_dir.split("/")
    if os.path.exists(os.path.join(leaf_dir, "calibration_performance.csv")):
        csv_data = pd.read_csv(os.path.join(leaf_dir, "calibration_performance.csv"), index_col=0)
        csv_records = csv_data.transpose().to_dict("records")

        for record in csv_records:
            record["dataset"] = dataset_map.get(dataset_name, dataset_name)
            record["model"] = model_name_map.get(model_name, model_name)
            record["dataset_size"] = dataset_size.get(dataset_name, None)

        hedged_qa_all_records.extend(csv_records)
    else:
        print(model_name, dataset_name, "missing calibration_performance.csv")

# %%
hedged_qa_detailed_records = []

for _, record in pd.DataFrame(hedged_qa_all_records).iterrows():
    lc = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Linguistic Confidence",
      "Hedged QA Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Hedged QA Generalised ECE": record["original_lc_generalised_ECE"],
    }
    hedged_qa_detailed_records.append(lc)
    su = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Semantic Uncertainty",
      "Hedged QA Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Hedged QA Generalised ECE": record["original_lc_generalised_ECE"],
    }
    hedged_qa_detailed_records.append(su)
    tp = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Token Probability",
      "Hedged QA Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Hedged QA Generalised ECE": record["original_lc_generalised_ECE"],
    }
    hedged_qa_detailed_records.append(tp)

hedged_qa_df = pd.DataFrame(hedged_qa_detailed_records)
hedged_qa_df
# Out:
#        Dataset               Model              Estimator  \
# 0     SQuAD2.0         GPT-OSS-20B  Linguistic Confidence
# 1     SQuAD2.0         GPT-OSS-20B   Semantic Uncertainty
# 2     SQuAD2.0         GPT-OSS-20B      Token Probability
# 3     SQuAD2.0    Mistral-7B-Inst.  Linguistic Confidence
# 4     SQuAD2.0    Mistral-7B-Inst.   Semantic Uncertainty
# 5     SQuAD2.0    Mistral-7B-Inst.      Token Probability
# 6     SQuAD2.0  Llama-3.1-8B-Inst.  Linguistic Confidence
# 7     SQuAD2.0  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 8     SQuAD2.0  Llama-3.1-8B-Inst.      Token Probability
# 9     SQuAD2.0      Qwen3-8B-Inst.  Linguistic Confidence
# 10    SQuAD2.0      Qwen3-8B-Inst.   Semantic Uncertainty
# 11    SQuAD2.0      Qwen3-8B-Inst.      Token Probability
# 12        MMLU         GPT-OSS-20B  Linguistic Confidence
# 13        MMLU         GPT-OSS-20B   Semantic Uncertainty
# 14        MMLU         GPT-OSS-20B      Token Probability
# 15        MMLU    Mistral-7B-Inst.  Linguistic Confidence
# 16        MMLU    Mistral-7B-Inst.   Semantic Uncertainty
# 17        MMLU    Mistral-7B-Inst.      Token Probability
# 18        MMLU  Llama-3.1-8B-Inst.  Linguistic Confidence
# 19        MMLU  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 20        MMLU  Llama-3.1-8B-Inst.      Token Probability
# 21        MMLU      Qwen3-8B-Inst.  Linguistic Confidence
# 22        MMLU      Qwen3-8B-Inst.   Semantic Uncertainty
# 23        MMLU      Qwen3-8B-Inst.      Token Probability
# 24  TruthfulQA         GPT-OSS-20B  Linguistic Confidence
# 25  TruthfulQA         GPT-OSS-20B   Semantic Uncertainty
# 26  TruthfulQA         GPT-OSS-20B      Token Probability
# 27  TruthfulQA    Mistral-7B-Inst.  Linguistic Confidence
# 28  TruthfulQA    Mistral-7B-Inst.   Semantic Uncertainty
# 29  TruthfulQA    Mistral-7B-Inst.      Token Probability
# 30  TruthfulQA  Llama-3.1-8B-Inst.  Linguistic Confidence
# 31  TruthfulQA  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 32  TruthfulQA  Llama-3.1-8B-Inst.      Token Probability
# 33  TruthfulQA      Qwen3-8B-Inst.  Linguistic Confidence
# 34  TruthfulQA      Qwen3-8B-Inst.   Semantic Uncertainty
# 35  TruthfulQA      Qwen3-8B-Inst.      Token Probability
#
#     Hedged QA Faithfulness Divergence  Hedged QA Generalised ECE
# 0                            2.783112                   0.371017
# 1                            2.783112                   0.371017
# 2                            2.783112                   0.371017
# 3                            2.482342                   0.339802
# 4                            2.482342                   0.339802
# 5                            2.482342                   0.339802
# 6                            1.610278                   0.258079
# 7                            1.610278                   0.258079
# 8                            1.610278                   0.258079
# 9                            2.579218                   0.356738
# 10                           2.579218                   0.356738
# 11                           2.579218                   0.356738
# 12                           0.931332                   0.189246
# 13                           0.931332                   0.189246
# 14                           0.931332                   0.189246
# 15                           1.564972                   0.306592
# 16                           1.564972                   0.306592
# 17                           1.564972                   0.306592
# 18                           0.950787                   0.161772
# 19                           0.950787                   0.161772
# 20                           0.950787                   0.161772
# 21                           1.028537                   0.170888
# 22                           1.028537                   0.170888
# 23                           1.028537                   0.170888
# 24                           1.308207                   0.243223
# 25                           1.308207                   0.243223
# 26                           1.308207                   0.243223
# 27                           1.260249                   0.260077
# 28                           1.260249                   0.260077
# 29                           1.260249                   0.260077
# 30                           0.748948                   0.229578
# 31                           0.748948                   0.229578
# 32                           0.748948                   0.229578
# 33                           1.589165                   0.318300
# 34                           1.589165                   0.318300
# 35                           1.589165                   0.318300

# %%
combined_df = pd.merge(in_domain_df, hedged_qa_df, on=["Dataset", "Model", "Estimator"], how="inner")
combined_df.to_dict("records")
# Out:
# [{'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 3.273351871782821,
#   'Calibrated Faithfulness Divergence': 0.6153363929110419,
#   'Original Generalised ECE': 0.4139609530390078,
#   'Calibrated Generalised ECE': 0.1839359052532692,
#   'Hedged QA Faithfulness Divergence': 2.783112326819216,
#   'Hedged QA Generalised ECE': 0.3710174823802434},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 3.273351871782821,
#   'Calibrated Faithfulness Divergence': 0.6432737850193566,
#   'Original Generalised ECE': 0.4139609530390078,
#   'Calibrated Generalised ECE': 0.164915178036266,
#   'Hedged QA Faithfulness Divergence': 2.783112326819216,
#   'Hedged QA Generalised ECE': 0.3710174823802434},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 3.273351871782821,
#   'Calibrated Faithfulness Divergence': 0.5546451335093834,
#   'Original Generalised ECE': 0.4139609530390078,
#   'Calibrated Generalised ECE': 0.1488273424465125,
#   'Hedged QA Faithfulness Divergence': 2.783112326819216,
#   'Hedged QA Generalised ECE': 0.3710174823802434},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.6274793548571758,
#   'Calibrated Faithfulness Divergence': 0.5987872741860294,
#   'Original Generalised ECE': 0.3743056708563125,
#   'Calibrated Generalised ECE': 0.1780554522175337,
#   'Hedged QA Faithfulness Divergence': 2.482342384469024,
#   'Hedged QA Generalised ECE': 0.3398020081646093},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.6274793548571758,
#   'Calibrated Faithfulness Divergence': 0.6683896354744765,
#   'Original Generalised ECE': 0.3743056708563125,
#   'Calibrated Generalised ECE': 0.1663344873010042,
#   'Hedged QA Faithfulness Divergence': 2.482342384469024,
#   'Hedged QA Generalised ECE': 0.3398020081646093},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.6274793548571758,
#   'Calibrated Faithfulness Divergence': 0.5696062668734597,
#   'Original Generalised ECE': 0.3743056708563125,
#   'Calibrated Generalised ECE': 0.1400927593455527,
#   'Hedged QA Faithfulness Divergence': 2.482342384469024,
#   'Hedged QA Generalised ECE': 0.3398020081646093},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.1549853077108123,
#   'Calibrated Faithfulness Divergence': 0.6989384059008885,
#   'Original Generalised ECE': 0.306455000877423,
#   'Calibrated Generalised ECE': 0.171445605288727,
#   'Hedged QA Faithfulness Divergence': 1.610277646277343,
#   'Hedged QA Generalised ECE': 0.2580793718825191},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.1549853077108123,
#   'Calibrated Faithfulness Divergence': 0.6175480450449734,
#   'Original Generalised ECE': 0.306455000877423,
#   'Calibrated Generalised ECE': 0.1169091443537354,
#   'Hedged QA Faithfulness Divergence': 1.610277646277343,
#   'Hedged QA Generalised ECE': 0.2580793718825191},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.1549853077108123,
#   'Calibrated Faithfulness Divergence': 0.643225419119187,
#   'Original Generalised ECE': 0.306455000877423,
#   'Calibrated Generalised ECE': 0.1451840214689907,
#   'Hedged QA Faithfulness Divergence': 1.610277646277343,
#   'Hedged QA Generalised ECE': 0.2580793718825191},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.604911083127611,
#   'Calibrated Faithfulness Divergence': 0.7594956953502062,
#   'Original Generalised ECE': 0.3494544495258581,
#   'Calibrated Generalised ECE': 0.2063426443452459,
#   'Hedged QA Faithfulness Divergence': 2.579217609423093,
#   'Hedged QA Generalised ECE': 0.3567380318580108},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.604911083127611,
#   'Calibrated Faithfulness Divergence': 0.6406676251892,
#   'Original Generalised ECE': 0.3494544495258581,
#   'Calibrated Generalised ECE': 0.1467233068069253,
#   'Hedged QA Faithfulness Divergence': 2.579217609423093,
#   'Hedged QA Generalised ECE': 0.3567380318580108},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.604911083127611,
#   'Calibrated Faithfulness Divergence': 0.6026227598774965,
#   'Original Generalised ECE': 0.3494544495258581,
#   'Calibrated Generalised ECE': 0.1571788784647488,
#   'Hedged QA Faithfulness Divergence': 2.579217609423093,
#   'Hedged QA Generalised ECE': 0.3567380318580108},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.8367073467484447,
#   'Calibrated Faithfulness Divergence': 0.679195499103448,
#   'Original Generalised ECE': 0.2328871168103198,
#   'Calibrated Generalised ECE': 0.1849088785627422,
#   'Hedged QA Faithfulness Divergence': 0.9313322715315844,
#   'Hedged QA Generalised ECE': 0.18924606836915},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.8367073467484447,
#   'Calibrated Faithfulness Divergence': 0.4754990275288935,
#   'Original Generalised ECE': 0.2328871168103198,
#   'Calibrated Generalised ECE': 0.1263850811381968,
#   'Hedged QA Faithfulness Divergence': 0.9313322715315844,
#   'Hedged QA Generalised ECE': 0.18924606836915},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.8367073467484447,
#   'Calibrated Faithfulness Divergence': 0.713359590427223,
#   'Original Generalised ECE': 0.2328871168103198,
#   'Calibrated Generalised ECE': 0.1772222017965392,
#   'Hedged QA Faithfulness Divergence': 0.9313322715315844,
#   'Hedged QA Generalised ECE': 0.18924606836915},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.7159680048015749,
#   'Calibrated Faithfulness Divergence': 0.5973749627693811,
#   'Original Generalised ECE': 0.323075690557442,
#   'Calibrated Generalised ECE': 0.1569011096391557,
#   'Hedged QA Faithfulness Divergence': 1.5649717277131725,
#   'Hedged QA Generalised ECE': 0.3065915768845367},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.7159680048015749,
#   'Calibrated Faithfulness Divergence': 0.5020368653731571,
#   'Original Generalised ECE': 0.323075690557442,
#   'Calibrated Generalised ECE': 0.1320853752181405,
#   'Hedged QA Faithfulness Divergence': 1.5649717277131725,
#   'Hedged QA Generalised ECE': 0.3065915768845367},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.7159680048015749,
#   'Calibrated Faithfulness Divergence': 0.5162709584412468,
#   'Original Generalised ECE': 0.323075690557442,
#   'Calibrated Generalised ECE': 0.1167011990537605,
#   'Hedged QA Faithfulness Divergence': 1.5649717277131725,
#   'Hedged QA Generalised ECE': 0.3065915768845367},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.3777792690318154,
#   'Calibrated Faithfulness Divergence': 0.5602315489733347,
#   'Original Generalised ECE': 0.2175632201326908,
#   'Calibrated Generalised ECE': 0.0977432197018322,
#   'Hedged QA Faithfulness Divergence': 0.950786554108674,
#   'Hedged QA Generalised ECE': 0.1617716401030677},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.3777792690318154,
#   'Calibrated Faithfulness Divergence': 0.6217274830091164,
#   'Original Generalised ECE': 0.2175632201326908,
#   'Calibrated Generalised ECE': 0.1043346662069952,
#   'Hedged QA Faithfulness Divergence': 0.950786554108674,
#   'Hedged QA Generalised ECE': 0.1617716401030677},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.3777792690318154,
#   'Calibrated Faithfulness Divergence': 0.5569739690666035,
#   'Original Generalised ECE': 0.2175632201326908,
#   'Calibrated Generalised ECE': 0.0930433969794049,
#   'Hedged QA Faithfulness Divergence': 0.950786554108674,
#   'Hedged QA Generalised ECE': 0.1617716401030677},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.1747744668094235,
#   'Calibrated Faithfulness Divergence': 0.5915535800172602,
#   'Original Generalised ECE': 0.2029139656597472,
#   'Calibrated Generalised ECE': 0.1324401437037423,
#   'Hedged QA Faithfulness Divergence': 1.028537193154343,
#   'Hedged QA Generalised ECE': 0.1708880894896547},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.1747744668094235,
#   'Calibrated Faithfulness Divergence': 0.5927208783638811,
#   'Original Generalised ECE': 0.2029139656597472,
#   'Calibrated Generalised ECE': 0.1020925087614529,
#   'Hedged QA Faithfulness Divergence': 1.028537193154343,
#   'Hedged QA Generalised ECE': 0.1708880894896547},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.1747744668094235,
#   'Calibrated Faithfulness Divergence': 0.5440048325640224,
#   'Original Generalised ECE': 0.2029139656597472,
#   'Calibrated Generalised ECE': 0.0943915035034706,
#   'Hedged QA Faithfulness Divergence': 1.028537193154343,
#   'Hedged QA Generalised ECE': 0.1708880894896547},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.558803538999651,
#   'Calibrated Faithfulness Divergence': 0.7868736456969443,
#   'Original Generalised ECE': 0.393610776644866,
#   'Calibrated Generalised ECE': 0.2347888371461955,
#   'Hedged QA Faithfulness Divergence': 1.3082074742399843,
#   'Hedged QA Generalised ECE': 0.2432229946228962},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.558803538999651,
#   'Calibrated Faithfulness Divergence': 0.6516106566513268,
#   'Original Generalised ECE': 0.393610776644866,
#   'Calibrated Generalised ECE': 0.2013270164416161,
#   'Hedged QA Faithfulness Divergence': 1.3082074742399843,
#   'Hedged QA Generalised ECE': 0.2432229946228962},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.558803538999651,
#   'Calibrated Faithfulness Divergence': 0.6798878155478937,
#   'Original Generalised ECE': 0.393610776644866,
#   'Calibrated Generalised ECE': 0.2121897046338859,
#   'Hedged QA Faithfulness Divergence': 1.3082074742399843,
#   'Hedged QA Generalised ECE': 0.2432229946228962},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.149523775562117,
#   'Calibrated Faithfulness Divergence': 0.7052021040828096,
#   'Original Generalised ECE': 0.3586147863472556,
#   'Calibrated Generalised ECE': 0.1926246819193924,
#   'Hedged QA Faithfulness Divergence': 1.2602489864472812,
#   'Hedged QA Generalised ECE': 0.260076677104771},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.149523775562117,
#   'Calibrated Faithfulness Divergence': 0.617368604034443,
#   'Original Generalised ECE': 0.3586147863472556,
#   'Calibrated Generalised ECE': 0.1770021888948626,
#   'Hedged QA Faithfulness Divergence': 1.2602489864472812,
#   'Hedged QA Generalised ECE': 0.260076677104771},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.149523775562117,
#   'Calibrated Faithfulness Divergence': 0.6368806265772124,
#   'Original Generalised ECE': 0.3586147863472556,
#   'Calibrated Generalised ECE': 0.1898572686269809,
#   'Hedged QA Faithfulness Divergence': 1.2602489864472812,
#   'Hedged QA Generalised ECE': 0.260076677104771},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.09832676631287,
#   'Calibrated Faithfulness Divergence': 0.570963758807724,
#   'Original Generalised ECE': 0.3580799665475965,
#   'Calibrated Generalised ECE': 0.1548692064590018,
#   'Hedged QA Faithfulness Divergence': 0.748948156055647,
#   'Hedged QA Generalised ECE': 0.2295781296509278},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.09832676631287,
#   'Calibrated Faithfulness Divergence': 0.5707021259848436,
#   'Original Generalised ECE': 0.3580799665475965,
#   'Calibrated Generalised ECE': 0.1671265857862059,
#   'Hedged QA Faithfulness Divergence': 0.748948156055647,
#   'Hedged QA Generalised ECE': 0.2295781296509278},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.09832676631287,
#   'Calibrated Faithfulness Divergence': 0.4881299310095243,
#   'Original Generalised ECE': 0.3580799665475965,
#   'Calibrated Generalised ECE': 0.135427893552261,
#   'Hedged QA Faithfulness Divergence': 0.748948156055647,
#   'Hedged QA Generalised ECE': 0.2295781296509278},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.564410089605344,
#   'Calibrated Faithfulness Divergence': 0.574759566278689,
#   'Original Generalised ECE': 0.4415782017936316,
#   'Calibrated Generalised ECE': 0.203661990842198,
#   'Hedged QA Faithfulness Divergence': 1.5891645824014775,
#   'Hedged QA Generalised ECE': 0.3182997020772422},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.564410089605344,
#   'Calibrated Faithfulness Divergence': 0.5902635339393993,
#   'Original Generalised ECE': 0.4415782017936316,
#   'Calibrated Generalised ECE': 0.1916083054452098,
#   'Hedged QA Faithfulness Divergence': 1.5891645824014775,
#   'Hedged QA Generalised ECE': 0.3182997020772422},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.564410089605344,
#   'Calibrated Faithfulness Divergence': 0.5736913347476505,
#   'Original Generalised ECE': 0.4415782017936316,
#   'Calibrated Generalised ECE': 0.1938443870157255,
#   'Hedged QA Faithfulness Divergence': 1.5891645824014775,
#   'Hedged QA Generalised ECE': 0.3182997020772422}]

# %%
from collections import defaultdict


ESTIMATOR_ORDER = ["Linguistic Confidence", "Semantic Uncertainty", "Token Probability"]

ESTIMATOR_LABELS = {
    "Linguistic Confidence": "Linguistic Conf.",
    "Semantic Uncertainty":  "Semantic Unc.",
    "Token Probability":     "Token Prob.",
}


def _fmt(value: float, decimals: int = 3) -> str:
    return f"{value:.{decimals}f}"


def _arrow(orig: float, calib: float, decimals: int = 3) -> str:
    return f"${_fmt(orig, decimals)} \\to {_fmt(calib, decimals)}$"


def generate_latex_table(
    data: list[dict],
    caption: str = "Calibration results across datasets, models, and estimators. Lower is better for all metrics.",
    label: str = "tab:results",
    decimals: int = 3,
    dataset_order: list[str] | None = None,
    model_order: list[str] | None = None,
) -> str:
    """
    Convert a list of result dicts into a LaTeX table string.

    Args:
        data:          List of result dicts (see module docstring for expected keys).
        caption:       Table caption.
        label:         LaTeX label for \\ref{}.
        decimals:      Decimal places for all numeric values.
        dataset_order: Optional explicit ordering of datasets.
                       Defaults to insertion order found in data.
        model_order:   Optional explicit ordering of models within each dataset.
                       Defaults to insertion order found in data.

    Returns:
        A self-contained LaTeX string (table* environment).
        Required packages: booktabs, multirow, makecell.
    """
    # ── 1. Index data: dataset -> model -> estimator -> row ──────────────────
    index: dict[str, dict[str, dict[str, dict]]] = defaultdict(lambda: defaultdict(dict))
    seen_datasets: list[str] = []
    seen_models: dict[str, list[str]] = defaultdict(list)

    for row in data:
        ds   = row["Dataset"]
        mdl  = row["Model"]
        est  = row["Estimator"]

        if ds not in seen_datasets:
            seen_datasets.append(ds)
        if mdl not in seen_models[ds]:
            seen_models[ds].append(mdl)

        index[ds][mdl][est] = row

    datasets = dataset_order if dataset_order is not None else seen_datasets
    
    def get_models(ds):
        if model_order is not None:
            return [m for m in model_order if m in index[ds]]
        return seen_models[ds]

    # ── 2. Build header ───────────────────────────────────────────────────────
    header = r"""\begin{table*}[ht]
\centering
\caption{""" + caption + r"""}
\label{""" + label + r"""}
\resizebox{\textwidth}{!}{%
\begin{tabular}{llllcccc}
\toprule
\multirow{3}{*}{Dataset}
  & \multirow{3}{*}{Model}
  & \multirow{3}{*}{Estimator}
  & \multicolumn{2}{c}{\textbf{In-Domain Calibration}}
  & \multicolumn{2}{c}{\textbf{Hedged QA}} \\
\cmidrule(lr){4-5} \cmidrule(lr){6-7}
  & & & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Calib.)}
       & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Calib.)}
       & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Hedged)}
       & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Hedged)} \\
\midrule"""

    # ── 3. Build body rows ────────────────────────────────────────────────────
    body_lines: list[str] = []

    for ds_idx, ds in enumerate(datasets):
        models = get_models(ds)
        n_ds_rows = len(models) * len(ESTIMATOR_ORDER)

        ds_cell = f"\\multirow{{{n_ds_rows}}}{{*}}{{{ds}}}"
        first_ds_row = True

        for mdl_idx, mdl in enumerate(models):
            estimators = ESTIMATOR_ORDER

            mdl_cell = f"\\multirow{{{len(estimators)}}}{{*}}{{{mdl}}}"
            first_mdl_row = True

            for est_idx, est in enumerate(estimators):
                row = index[ds][mdl].get(est)
                if row is None:
                    continue

                # In-domain calibration columns (vary per estimator)
                fd_cell  = _arrow(row["Original Faithfulness Divergence"],
                                  row["Calibrated Faithfulness Divergence"], decimals)
                ece_cell = _arrow(row["Original Generalised ECE"],
                                  row["Calibrated Generalised ECE"], decimals)

                # Hedged QA columns (same for all estimators of this model/dataset)
                if first_mdl_row:
                    hfd_cell = (f"\\multirow{{{len(estimators)}}}{{*}}{{"
                                + _arrow(row["Original Faithfulness Divergence"],
                                         row["Hedged QA Faithfulness Divergence"], decimals)
                                + "}")
                    hece_cell = (f"\\multirow{{{len(estimators)}}}{{*}}{{"
                                 + _arrow(row["Original Generalised ECE"],
                                          row["Hedged QA Generalised ECE"], decimals)
                                 + "}")
                else:
                    hfd_cell  = ""
                    hece_cell = ""

                est_label = ESTIMATOR_LABELS.get(est, est)

                # Assemble leading cells
                if first_ds_row and first_mdl_row:
                    leading = f" {ds_cell} & {mdl_cell}"
                elif first_mdl_row:
                    leading = f" & {mdl_cell}"
                else:
                    leading = f" &"

                line = (f"{leading} & {est_label}"
                        f" & {fd_cell} & {ece_cell}"
                        f" & {hfd_cell} & {hece_cell} \\\\")

                body_lines.append(line)
                first_ds_row   = False
                first_mdl_row  = False

            # Separator between models (not after the last model in a dataset)
            if mdl_idx < len(models) - 1:
                body_lines.append(r"\cmidrule(l){2-7}")

        # Separator between datasets (not after the last one)
        if ds_idx < len(datasets) - 1:
            body_lines.append(r"\midrule")

    # ── 4. Footer ─────────────────────────────────────────────────────────────
    footer = r"""\bottomrule
\end{tabular}%
}
\end{table*}"""

    return "\n".join([header, *body_lines, footer])


print(generate_latex_table(combined_df.to_dict("records"), caption="Sample table.", label="tab:sample"))
# Out:
# \begin{table*}[ht]
# \centering
# \caption{Sample table.}
# \label{tab:sample}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{llllcccc}
# \toprule
# \multirow{3}{*}{Dataset}
#   & \multirow{3}{*}{Model}
#   & \multirow{3}{*}{Estimator}
#   & \multicolumn{2}{c}{\textbf{In-Domain Calibration}}
#   & \multicolumn{2}{c}{\textbf{Hedged QA}} \\
# \cmidrule(lr){4-5} \cmidrule(lr){6-7}
#   & & & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Calib.)}
#        & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Calib.)}
#        & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Hedged)}
#        & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Hedged)} \\
# \midrule
#  \multirow{12}{*}{SQuAD2.0} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $3.273 \to 0.615$ & $0.414 \to 0.184$ & \multirow{3}{*}{$3.273 \to 2.783$} & \multirow{3}{*}{$0.414 \to 0.371$} \\
#  & & Semantic Unc. & $3.273 \to 0.643$ & $0.414 \to 0.165$ &  &  \\
#  & & Token Prob. & $3.273 \to 0.555$ & $0.414 \to 0.149$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $2.627 \to 0.599$ & $0.374 \to 0.178$ & \multirow{3}{*}{$2.627 \to 2.482$} & \multirow{3}{*}{$0.374 \to 0.340$} \\
#  & & Semantic Unc. & $2.627 \to 0.668$ & $0.374 \to 0.166$ &  &  \\
#  & & Token Prob. & $2.627 \to 0.570$ & $0.374 \to 0.140$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $2.155 \to 0.699$ & $0.306 \to 0.171$ & \multirow{3}{*}{$2.155 \to 1.610$} & \multirow{3}{*}{$0.306 \to 0.258$} \\
#  & & Semantic Unc. & $2.155 \to 0.618$ & $0.306 \to 0.117$ &  &  \\
#  & & Token Prob. & $2.155 \to 0.643$ & $0.306 \to 0.145$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $2.605 \to 0.759$ & $0.349 \to 0.206$ & \multirow{3}{*}{$2.605 \to 2.579$} & \multirow{3}{*}{$0.349 \to 0.357$} \\
#  & & Semantic Unc. & $2.605 \to 0.641$ & $0.349 \to 0.147$ &  &  \\
#  & & Token Prob. & $2.605 \to 0.603$ & $0.349 \to 0.157$ &  &  \\
# \midrule
#  \multirow{12}{*}{MMLU} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $2.837 \to 0.679$ & $0.233 \to 0.185$ & \multirow{3}{*}{$2.837 \to 0.931$} & \multirow{3}{*}{$0.233 \to 0.189$} \\
#  & & Semantic Unc. & $2.837 \to 0.475$ & $0.233 \to 0.126$ &  &  \\
#  & & Token Prob. & $2.837 \to 0.713$ & $0.233 \to 0.177$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $1.716 \to 0.597$ & $0.323 \to 0.157$ & \multirow{3}{*}{$1.716 \to 1.565$} & \multirow{3}{*}{$0.323 \to 0.307$} \\
#  & & Semantic Unc. & $1.716 \to 0.502$ & $0.323 \to 0.132$ &  &  \\
#  & & Token Prob. & $1.716 \to 0.516$ & $0.323 \to 0.117$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $1.378 \to 0.560$ & $0.218 \to 0.098$ & \multirow{3}{*}{$1.378 \to 0.951$} & \multirow{3}{*}{$0.218 \to 0.162$} \\
#  & & Semantic Unc. & $1.378 \to 0.622$ & $0.218 \to 0.104$ &  &  \\
#  & & Token Prob. & $1.378 \to 0.557$ & $0.218 \to 0.093$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $1.175 \to 0.592$ & $0.203 \to 0.132$ & \multirow{3}{*}{$1.175 \to 1.029$} & \multirow{3}{*}{$0.203 \to 0.171$} \\
#  & & Semantic Unc. & $1.175 \to 0.593$ & $0.203 \to 0.102$ &  &  \\
#  & & Token Prob. & $1.175 \to 0.544$ & $0.203 \to 0.094$ &  &  \\
# \midrule
#  \multirow{12}{*}{TruthfulQA} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $2.559 \to 0.787$ & $0.394 \to 0.235$ & \multirow{3}{*}{$2.559 \to 1.308$} & \multirow{3}{*}{$0.394 \to 0.243$} \\
#  & & Semantic Unc. & $2.559 \to 0.652$ & $0.394 \to 0.201$ &  &  \\
#  & & Token Prob. & $2.559 \to 0.680$ & $0.394 \to 0.212$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $2.150 \to 0.705$ & $0.359 \to 0.193$ & \multirow{3}{*}{$2.150 \to 1.260$} & \multirow{3}{*}{$0.359 \to 0.260$} \\
#  & & Semantic Unc. & $2.150 \to 0.617$ & $0.359 \to 0.177$ &  &  \\
#  & & Token Prob. & $2.150 \to 0.637$ & $0.359 \to 0.190$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $2.098 \to 0.571$ & $0.358 \to 0.155$ & \multirow{3}{*}{$2.098 \to 0.749$} & \multirow{3}{*}{$0.358 \to 0.230$} \\
#  & & Semantic Unc. & $2.098 \to 0.571$ & $0.358 \to 0.167$ &  &  \\
#  & & Token Prob. & $2.098 \to 0.488$ & $0.358 \to 0.135$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $2.564 \to 0.575$ & $0.442 \to 0.204$ & \multirow{3}{*}{$2.564 \to 1.589$} & \multirow{3}{*}{$0.442 \to 0.318$} \\
#  & & Semantic Unc. & $2.564 \to 0.590$ & $0.442 \to 0.192$ &  &  \\
#  & & Token Prob. & $2.564 \to 0.574$ & $0.442 \to 0.194$ &  &  \\
# \bottomrule
# \end{tabular}%
# }
# \end{table*}
