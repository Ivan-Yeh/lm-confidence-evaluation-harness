# %%
import os
import pandas as pd
import numpy as np

# %%
methods_names = {
    "dist_linguistic_confidence": "Dist. Ling. Conf.",
    "dist_semantic_uncertainty": "Dist. Semantic Unc.",
    "dist_lnll": "Dist. Token Prob"
}

dataset_size = {
    "mmlu": 116000,
    "squadv2": 130000,
    "truthful_qa": 817
}

dataset_map = {
    "mmlu": "MMLU",
    "squadv2": "SQuAD2.0",
    "truthful_qa": "TruthfulQA"
}

model_name_map = {
    "Llama-3.1-8B-Instruct": "Llama-3.1-8B-Inst.",
    "Meta-Llama-3-8B-Instruct": "Llama-3-8B-Inst.",
    "Qwen2.5-7B-Instruct": "Qwen2.5-7B-Inst.",
    "Qwen3-8B": "Qwen3-8B-Inst.",
    "Mistral-7B-Instruct-v0.3": "Mistral-7B-Inst.",
    "gpt-oss-20b": "GPT-OSS-20B",
}

# %%
prompt_type = "direct_qa"
results_dir = f"/hdd/ivny/{prompt_type}_in_domain_calibration"

# list all leaf nodes in results_dir
leaf_dirs = []
for root, dirs, files in os.walk(results_dir):
    if not dirs:  # if there are no subdirectories, it's a leaf node
        leaf_dirs.append(root)

all_records = []
for leaf_dir in leaf_dirs:
    _, _, _, _, dataset_name, _, model_name = leaf_dir.split("/")
    if os.path.exists(os.path.join(leaf_dir, "calibration_performance.csv")):
        csv_data = pd.read_csv(os.path.join(leaf_dir, "calibration_performance.csv"), index_col=0)
        csv_records = csv_data.transpose().to_dict("records")

        for record in csv_records:
            record["dataset"] = dataset_map.get(dataset_name, dataset_name)
            record["model"] = model_name_map.get(model_name, model_name)
            record["dataset_size"] = dataset_size.get(dataset_name, None)

        all_records.extend(csv_records)
    else:
        print(model_name, dataset_name, "missing calibration_performance.csv")

# %%
full_df = pd.DataFrame(all_records)
full_df
# Out:
#     original_lc_generalised_ECE  original_lc_faithfulness_divergence  \
# 0                      0.388875                             2.264707
# 1                      0.350390                             1.978019
# 2                      0.305406                             1.593604
# 3                      0.369798                             2.102932
# 4                      0.151864                             0.579284
# 5                      0.239395                             1.198330
# 6                      0.190048                             0.925248
# 7                      0.166724                             0.901899
# 8                      0.392331                             2.265177
# 9                      0.374018                             1.781702
# 10                     0.426676                             1.828475
# 11                     0.442117                             2.053794
#
#     original_lc_ece_mean  original_lc_dAUROC  original_lc_auroc_mean  \
# 0               0.360898              0.5103                0.500348
# 1               0.328392              0.4846                0.474338
# 2               0.273644              0.5382                0.531963
# 3               0.348138              0.5194                0.519346
# 4               0.094998              0.5062                0.511461
# 5               0.207488              0.5310                0.536319
# 6               0.137413              0.5297                0.556111
# 7               0.089968              0.5487                0.565632
# 8               0.380557              0.5683                0.570227
# 9               0.368974              0.5664                0.604006
# 10              0.424060              0.6051                0.649914
# 11              0.436813              0.5981                0.648487
#
#     original_tp_generalised_ECE  original_tp_faithfulness_divergence  \
# 0                      0.275394                             0.936204
# 1                      0.287634                             4.261251
# 2                      0.186093                             1.429562
# 3                      0.453795                           189.090083
# 4                      0.148043                             1.875741
# 5                      0.381067                           335.579049
# 6                      0.260864                             4.656756
# 7                      0.280934                           223.551016
# 8                      0.194547                             0.743427
# 9                      0.206740                             4.987962
# 10                     0.097593                             0.561233
# 11                     0.461352                            48.374603
#
#     original_tp_ece_mean  original_tp_dAUROC  original_tp_auroc_mean  ...  \
# 0               0.270902             0.59150                0.637435  ...
# 1               0.285989             0.62570                0.671154  ...
# 2               0.172370             0.65700                0.700269  ...
# 3               0.452984             0.62495                0.638530  ...
# 4               0.099184             0.53325                0.538044  ...
# 5               0.379346             0.63730                0.658290  ...
# 6               0.251987             0.64495                0.673481  ...
# 7               0.277312             0.52290                0.505690  ...
# 8               0.190556             0.58520                0.616068  ...
# 9               0.194864             0.53760                0.532915  ...
# 10              0.094125             0.64380                0.702701  ...
# 11              0.458924             0.60170                0.633849  ...
#
#     calibrated_su_rewritten_lc_dAUROC  calibrated_su_rewritten_lc_auroc_mean  \
# 0                              0.6275                               0.649228
# 1                              0.5322                               0.535978
# 2                              0.6239                               0.653930
# 3                              0.5662                               0.586380
# 4                              0.7192                               0.748724
# 5                              0.5501                               0.571734
# 6                              0.6568                               0.705205
# 7                              0.5543                               0.579526
# 8                              0.6256                               0.672801
# 9                              0.6048                               0.646743
# 10                             0.6298                               0.671257
# 11                             0.6611                               0.717240
#
#     calibrated_su_beta_guided_lc_generalised_ECE  \
# 0                                       0.250048
# 1                                       0.216990
# 2                                       0.171022
# 3                                       0.231886
# 4                                       0.086329
# 5                                       0.141643
# 6                                       0.108194
# 7                                       0.117603
# 8                                       0.274458
# 9                                       0.275430
# 10                                      0.318831
# 11                                      0.330006
#
#     calibrated_su_beta_guided_lc_faithfulness_divergence  \
# 0                                            0.938402
# 1                                            0.906549
# 2                                            0.792242
# 3                                            0.846493
# 4                                            0.528301
# 5                                            0.674156
# 6                                            0.624603
# 7                                            0.737846
# 8                                            0.804022
# 9                                            0.844185
# 10                                           0.844742
# 11                                           0.962776
#
#     calibrated_su_beta_guided_lc_ece_mean  \
# 0                                0.248457
# 1                                0.215836
# 2                                0.167130
# 3                                0.230577
# 4                                0.041048
# 5                                0.135956
# 6                                0.089345
# 7                                0.091175
# 8                                0.272237
# 9                                0.275034
# 10                               0.317633
# 11                               0.326802
#
#     calibrated_su_beta_guided_lc_dAUROC  \
# 0                                0.5379
# 1                                0.4910
# 2                                0.5367
# 3                                0.5205
# 4                                0.6060
# 5                                0.5459
# 6                                0.5949
# 7                                0.5289
# 8                                0.6066
# 9                                0.5934
# 10                               0.6211
# 11                               0.5994
#
#     calibrated_su_beta_guided_lc_auroc_mean     dataset               model  \
# 0                                  0.561052    SQuAD2.0         GPT-OSS-20B
# 1                                  0.487251    SQuAD2.0    Mistral-7B-Inst.
# 2                                  0.559869    SQuAD2.0  Llama-3.1-8B-Inst.
# 3                                  0.521469    SQuAD2.0      Qwen3-8B-Inst.
# 4                                  0.623581        MMLU         GPT-OSS-20B
# 5                                  0.566116        MMLU    Mistral-7B-Inst.
# 6                                  0.632701        MMLU  Llama-3.1-8B-Inst.
# 7                                  0.552656        MMLU      Qwen3-8B-Inst.
# 8                                  0.654762  TruthfulQA         GPT-OSS-20B
# 9                                  0.641371  TruthfulQA    Mistral-7B-Inst.
# 10                                 0.662782  TruthfulQA  Llama-3.1-8B-Inst.
# 11                                 0.639606  TruthfulQA      Qwen3-8B-Inst.
#
#     dataset_size
# 0         130000
# 1         130000
# 2         130000
# 3         130000
# 4         116000
# 5         116000
# 6         116000
# 7         116000
# 8            817
# 9            817
# 10           817
# 11           817
#
# [12 rows x 63 columns]

# %%
full_df.columns
# Out:
# Index(['original_lc_generalised_ECE', 'original_lc_faithfulness_divergence',
#        'original_lc_ece_mean', 'original_lc_dAUROC', 'original_lc_auroc_mean',
#        'original_tp_generalised_ECE', 'original_tp_faithfulness_divergence',
#        'original_tp_ece_mean', 'original_tp_dAUROC', 'original_tp_auroc_mean',
#        'original_su_generalised_ECE', 'original_su_faithfulness_divergence',
#        'original_su_ece_mean', 'original_su_dAUROC', 'original_su_auroc_mean',
#        'calibrated_lc_generalised_ECE',
#        'calibrated_lc_faithfulness_divergence', 'calibrated_lc_ece_mean',
#        'calibrated_lc_dAUROC', 'calibrated_lc_auroc_mean',
#        'calibrated_tp_generalised_ECE',
#        'calibrated_tp_faithfulness_divergence', 'calibrated_tp_ece_mean',
#        'calibrated_tp_dAUROC', 'calibrated_tp_auroc_mean',
#        'calibrated_su_generalised_ECE',
#        'calibrated_su_faithfulness_divergence', 'calibrated_su_ece_mean',
#        'calibrated_su_dAUROC', 'calibrated_su_auroc_mean',
#        'calibrated_lc_rewritten_lc_generalised_ECE',
#        'calibrated_lc_rewritten_lc_faithfulness_divergence',
#        'calibrated_lc_rewritten_lc_ece_mean',
#        'calibrated_lc_rewritten_lc_dAUROC',
#        'calibrated_lc_rewritten_lc_auroc_mean',
#        'calibrated_lc_beta_guided_lc_generalised_ECE',
#        'calibrated_lc_beta_guided_lc_faithfulness_divergence',
#        'calibrated_lc_beta_guided_lc_ece_mean',
#        'calibrated_lc_beta_guided_lc_dAUROC',
#        'calibrated_lc_beta_guided_lc_auroc_mean',
#        'calibrated_tp_rewritten_lc_generalised_ECE',
#        'calibrated_tp_rewritten_lc_faithfulness_divergence',
#        'calibrated_tp_rewritten_lc_ece_mean',
#        'calibrated_tp_rewritten_lc_dAUROC',
#        'calibrated_tp_rewritten_lc_auroc_mean',
#        'calibrated_tp_beta_guided_lc_generalised_ECE',
#        'calibrated_tp_beta_guided_lc_faithfulness_divergence',
#        'calibrated_tp_beta_guided_lc_ece_mean',
#        'calibrated_tp_beta_guided_lc_dAUROC',
#        'calibrated_tp_beta_guided_lc_auroc_mean',
#        'calibrated_su_rewritten_lc_generalised_ECE',
#        'calibrated_su_rewritten_lc_faithfulness_divergence',
#        'calibrated_su_rewritten_lc_ece_mean',
#        'calibrated_su_rewritten_lc_dAUROC',
#        'calibrated_su_rewritten_lc_auroc_mean',
#        'calibrated_su_beta_guided_lc_generalised_ECE',
#        'calibrated_su_beta_guided_lc_faithfulness_divergence',
#        'calibrated_su_beta_guided_lc_ece_mean',
#        'calibrated_su_beta_guided_lc_dAUROC',
#        'calibrated_su_beta_guided_lc_auroc_mean', 'dataset', 'model',
#        'dataset_size'],
#       dtype='str')

# %%
in_domain_detailed_records = []

for _, record in full_df.iterrows():
    lc = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Linguistic Confidence",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_lc_rewritten_lc_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_lc_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(lc)
    su = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Semantic Uncertainty",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_su_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_su_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(su)
    tp = {
      "Dataset": record["dataset"],
      "Model": record["model"],
      "Estimator": "Token Probability",
      "Original Faithfulness Divergence": record["original_lc_faithfulness_divergence"],
      "Calibrated Faithfulness Divergence": record["calibrated_tp_rewritten_lc_faithfulness_divergence"],
      "Original Generalised ECE": record["original_lc_generalised_ECE"],
      "Calibrated Generalised ECE": record["calibrated_tp_rewritten_lc_generalised_ECE"]
    }
    in_domain_detailed_records.append(tp)

# %%
in_domain_df = pd.DataFrame(in_domain_detailed_records)
in_domain_df
# Out:
#        Dataset               Model              Estimator  \
# 0     SQuAD2.0         GPT-OSS-20B  Linguistic Confidence
# 1     SQuAD2.0         GPT-OSS-20B   Semantic Uncertainty
# 2     SQuAD2.0         GPT-OSS-20B      Token Probability
# 3     SQuAD2.0    Mistral-7B-Inst.  Linguistic Confidence
# 4     SQuAD2.0    Mistral-7B-Inst.   Semantic Uncertainty
# 5     SQuAD2.0    Mistral-7B-Inst.      Token Probability
# 6     SQuAD2.0  Llama-3.1-8B-Inst.  Linguistic Confidence
# 7     SQuAD2.0  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 8     SQuAD2.0  Llama-3.1-8B-Inst.      Token Probability
# 9     SQuAD2.0      Qwen3-8B-Inst.  Linguistic Confidence
# 10    SQuAD2.0      Qwen3-8B-Inst.   Semantic Uncertainty
# 11    SQuAD2.0      Qwen3-8B-Inst.      Token Probability
# 12        MMLU         GPT-OSS-20B  Linguistic Confidence
# 13        MMLU         GPT-OSS-20B   Semantic Uncertainty
# 14        MMLU         GPT-OSS-20B      Token Probability
# 15        MMLU    Mistral-7B-Inst.  Linguistic Confidence
# 16        MMLU    Mistral-7B-Inst.   Semantic Uncertainty
# 17        MMLU    Mistral-7B-Inst.      Token Probability
# 18        MMLU  Llama-3.1-8B-Inst.  Linguistic Confidence
# 19        MMLU  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 20        MMLU  Llama-3.1-8B-Inst.      Token Probability
# 21        MMLU      Qwen3-8B-Inst.  Linguistic Confidence
# 22        MMLU      Qwen3-8B-Inst.   Semantic Uncertainty
# 23        MMLU      Qwen3-8B-Inst.      Token Probability
# 24  TruthfulQA         GPT-OSS-20B  Linguistic Confidence
# 25  TruthfulQA         GPT-OSS-20B   Semantic Uncertainty
# 26  TruthfulQA         GPT-OSS-20B      Token Probability
# 27  TruthfulQA    Mistral-7B-Inst.  Linguistic Confidence
# 28  TruthfulQA    Mistral-7B-Inst.   Semantic Uncertainty
# 29  TruthfulQA    Mistral-7B-Inst.      Token Probability
# 30  TruthfulQA  Llama-3.1-8B-Inst.  Linguistic Confidence
# 31  TruthfulQA  Llama-3.1-8B-Inst.   Semantic Uncertainty
# 32  TruthfulQA  Llama-3.1-8B-Inst.      Token Probability
# 33  TruthfulQA      Qwen3-8B-Inst.  Linguistic Confidence
# 34  TruthfulQA      Qwen3-8B-Inst.   Semantic Uncertainty
# 35  TruthfulQA      Qwen3-8B-Inst.      Token Probability
#
#     Original Faithfulness Divergence  Calibrated Faithfulness Divergence  \
# 0                           2.264707                            0.763558
# 1                           2.264707                            0.474030
# 2                           2.264707                            0.665294
# 3                           1.978019                            0.700965
# 4                           1.978019                            0.486909
# 5                           1.978019                            0.682333
# 6                           1.593604                            0.643169
# 7                           1.593604                            0.495237
# 8                           1.593604                            0.623469
# 9                           2.102932                            0.751036
# 10                          2.102932                            0.480114
# 11                          2.102932                            0.670257
# 12                          0.579284                            1.118444
# 13                          0.579284                            0.563032
# 14                          0.579284                            1.333383
# 15                          1.198330                            0.556778
# 16                          1.198330                            0.471216
# 17                          1.198330                            0.578411
# 18                          0.925248                            0.601634
# 19                          0.925248                            0.460936
# 20                          0.925248                            0.664729
# 21                          0.901899                            0.769817
# 22                          0.901899                            0.563553
# 23                          0.901899                            0.643131
# 24                          2.265177                            0.677998
# 25                          2.265177                            0.475081
# 26                          2.265177                            0.645379
# 27                          1.781702                            0.710137
# 28                          1.781702                            0.476969
# 29                          1.781702                            0.727084
# 30                          1.828475                            0.712143
# 31                          1.828475                            0.466826
# 32                          1.828475                            0.636388
# 33                          2.053794                            0.706933
# 34                          2.053794                            0.463559
# 35                          2.053794                            0.623059
#
#     Original Generalised ECE  Calibrated Generalised ECE
# 0                   0.388875                    0.231877
# 1                   0.388875                    0.136523
# 2                   0.388875                    0.191943
# 3                   0.350390                    0.184583
# 4                   0.350390                    0.115826
# 5                   0.350390                    0.181351
# 6                   0.305406                    0.159553
# 7                   0.305406                    0.121841
# 8                   0.305406                    0.145380
# 9                   0.369798                    0.224963
# 10                  0.369798                    0.176117
# 11                  0.369798                    0.188663
# 12                  0.151864                    0.128119
# 13                  0.151864                    0.089401
# 14                  0.151864                    0.138149
# 15                  0.239395                    0.119513
# 16                  0.239395                    0.112934
# 17                  0.239395                    0.109021
# 18                  0.190048                    0.120127
# 19                  0.190048                    0.091510
# 20                  0.190048                    0.096489
# 21                  0.166724                    0.147628
# 22                  0.166724                    0.144801
# 23                  0.166724                    0.112614
# 24                  0.392331                    0.229837
# 25                  0.392331                    0.178610
# 26                  0.392331                    0.226712
# 27                  0.374018                    0.227309
# 28                  0.374018                    0.237641
# 29                  0.374018                    0.247858
# 30                  0.426676                    0.268676
# 31                  0.426676                    0.254453
# 32                  0.426676                    0.247120
# 33                  0.442117                    0.270119
# 34                  0.442117                    0.246656
# 35                  0.442117                    0.242138

# %%
common_path = "/hdd/ivny/results"
if os.path.exists(common_path):
    results_dir = common_path
else:
    results_dir = f"/home/ivan/lm-confidence-evaluation-harness/ivny/results"

mmlu_path = os.path.join(results_dir, "mmlu/hedged_qa_unified_lc")
squadv2_path = os.path.join(results_dir, "squadv2/hedged_qa_unified_lc")
truthfulqa_path = os.path.join(results_dir, "truthful_qa/hedged_qa_unified_lc")

# %%
def get_latest_subdir(path):
    subdirs = [os.path.join(path, d) for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    return max(subdirs, key=os.path.getmtime) if subdirs else None

results_dir = "/hdd/ivny/results" if os.path.exists("/hdd/ivny") else "/home/ivan/lm-confidence-evaluation-harness/ivny/results"

paths = {
    "mmlu":        os.path.join(results_dir, "mmlu",        f"{prompt_type}_unified_lc"),
    "squadv2":     os.path.join(results_dir, "squadv2",     f"{prompt_type}_unified_lc"),
    "truthful_qa": os.path.join(results_dir, "truthful_qa", f"{prompt_type}_unified_lc"),
}

all_records_hedged = []
for dataset_name, path in paths.items():
    if not os.path.exists(path):
        print(f"Missing: {path}")
        continue
    seen_models = {}  # model_name -> (latest_dir, latest_mtime)
    for org in os.listdir(path):
        org_path = os.path.join(path, org)
        if not os.path.isdir(org_path):
            continue
        for model_name in os.listdir(org_path):
            model_path = os.path.join(org_path, model_name)
            if not os.path.isdir(model_path):
                continue
            latest = get_latest_subdir(model_path)
            if latest is None:
                continue
            mtime = os.path.getmtime(latest)
            if model_name not in seen_models or mtime > seen_models[model_name][1]:
                seen_models[model_name] = (latest, mtime)

    for model_name, (latest_dir, _) in seen_models.items():
        csv_path = os.path.join(latest_dir, "eval_metrics.csv")
        if not os.path.exists(csv_path):
            print(f"Missing eval_metrics.csv: {latest_dir}")
            continue
        try:
            row = pd.read_csv(csv_path).iloc[0]
            all_records_hedged.append({
                "Model":                  model_name_map.get(model_name, model_name),
                "Dataset":                dataset_map.get(dataset_name, dataset_name),
                "Estimator":             "Linguistic Confidence",
                "dataset_size":           dataset_size.get(dataset_name, None),
                "Hedged QA Generalised ECE":        row["generalised_ece"],
                "Hedged QA Faithfulness Divergence": row["faithfulness_divergence"],
            })
            all_records_hedged.append({
                "Model":                  model_name_map.get(model_name, model_name),
                "Dataset":                dataset_map.get(dataset_name, dataset_name),
                "Estimator":             "Token Probability",
                "dataset_size":           dataset_size.get(dataset_name, None),
                "Hedged QA Generalised ECE":        row["generalised_ece"],
                "Hedged QA Faithfulness Divergence": row["faithfulness_divergence"],
            })
            all_records_hedged.append({
                "Model":                  model_name_map.get(model_name, model_name),
                "Dataset":                dataset_map.get(dataset_name, dataset_name),
                "Estimator":             "Semantic Uncertainty",
                "dataset_size":           dataset_size.get(dataset_name, None),
                "Hedged QA Generalised ECE":        row["generalised_ece"],
                "Hedged QA Faithfulness Divergence": row["faithfulness_divergence"],
            })
        except Exception as e:
            print(f"Error processing {csv_path}: {e}")

hedged_qa_df = pd.DataFrame(all_records_hedged)
# Out:
# Error processing /hdd/ivny/results/mmlu/hedged_qa_unified_lc/openai/gpt-oss-120b/2026-04-19_03-27-57/eval_metrics.csv: No columns to parse from file
# Missing eval_metrics.csv: /hdd/ivny/results/mmlu/hedged_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-55-11
# Missing eval_metrics.csv: /hdd/ivny/results/mmlu/hedged_qa_unified_lc/meta-llama/Llama-3.3-70B-Instruct-Turbo/2026-04-19_03-27-57
# Error processing /hdd/ivny/results/mmlu/hedged_qa_unified_lc/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-19_03-27-57/eval_metrics.csv: No columns to parse from file
# Error processing /hdd/ivny/results/squadv2/hedged_qa_unified_lc/openai/gpt-oss-120b/2026-04-19_03-30-46/eval_metrics.csv: No columns to parse from file
# Missing eval_metrics.csv: /hdd/ivny/results/squadv2/hedged_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-56-21
# Error processing /hdd/ivny/results/squadv2/hedged_qa_unified_lc/meta-llama/Llama-3.3-70B-Instruct-Turbo/2026-04-19_03-30-46/eval_metrics.csv: No columns to parse from file
# Error processing /hdd/ivny/results/squadv2/hedged_qa_unified_lc/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-19_03-30-46/eval_metrics.csv: No columns to parse from file
# Error processing /hdd/ivny/results/truthful_qa/hedged_qa_unified_lc/openai/gpt-oss-120b/2026-04-19_03-26-00/eval_metrics.csv: No columns to parse from file
# Missing eval_metrics.csv: /hdd/ivny/results/truthful_qa/hedged_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-53-48
# Error processing /hdd/ivny/results/truthful_qa/hedged_qa_unified_lc/meta-llama/Llama-3.3-70B-Instruct-Turbo/2026-04-19_03-26-00/eval_metrics.csv: No columns to parse from file
# Error processing /hdd/ivny/results/truthful_qa/hedged_qa_unified_lc/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-19_03-26-00/eval_metrics.csv: No columns to parse from file

# %%
combined_df = pd.merge(in_domain_df, hedged_qa_df, on=["Dataset", "Model", "Estimator"], how="inner")
combined_df.to_dict("records")
# Out:
# [{'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.2647065082075195,
#   'Calibrated Faithfulness Divergence': 0.7635581357099704,
#   'Original Generalised ECE': 0.3888754781464516,
#   'Calibrated Generalised ECE': 0.2318773914149126,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3537496784093773,
#   'Hedged QA Faithfulness Divergence': 2.278297418905003},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.2647065082075195,
#   'Calibrated Faithfulness Divergence': 0.4740295066996191,
#   'Original Generalised ECE': 0.3888754781464516,
#   'Calibrated Generalised ECE': 0.1365234989229198,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3537496784093773,
#   'Hedged QA Faithfulness Divergence': 2.278297418905003},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.2647065082075195,
#   'Calibrated Faithfulness Divergence': 0.665293877134471,
#   'Original Generalised ECE': 0.3888754781464516,
#   'Calibrated Generalised ECE': 0.1919432025508377,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3537496784093773,
#   'Hedged QA Faithfulness Divergence': 2.278297418905003},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.9780186705503788,
#   'Calibrated Faithfulness Divergence': 0.7009646977238332,
#   'Original Generalised ECE': 0.3503897967968142,
#   'Calibrated Generalised ECE': 0.1845831331141755,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3367513383737517,
#   'Hedged QA Faithfulness Divergence': 2.053719895938888},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.9780186705503788,
#   'Calibrated Faithfulness Divergence': 0.4869087141292374,
#   'Original Generalised ECE': 0.3503897967968142,
#   'Calibrated Generalised ECE': 0.1158259140959739,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3367513383737517,
#   'Hedged QA Faithfulness Divergence': 2.053719895938888},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.9780186705503788,
#   'Calibrated Faithfulness Divergence': 0.6823326367346978,
#   'Original Generalised ECE': 0.3503897967968142,
#   'Calibrated Generalised ECE': 0.1813505645610172,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3367513383737517,
#   'Hedged QA Faithfulness Divergence': 2.053719895938888},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.5936036473018815,
#   'Calibrated Faithfulness Divergence': 0.6431689297301058,
#   'Original Generalised ECE': 0.3054064276446021,
#   'Calibrated Generalised ECE': 0.1595528089305081,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.2310970809507165,
#   'Hedged QA Faithfulness Divergence': 1.2385826887250488},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.5936036473018815,
#   'Calibrated Faithfulness Divergence': 0.495237046349204,
#   'Original Generalised ECE': 0.3054064276446021,
#   'Calibrated Generalised ECE': 0.1218407640302774,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.2310970809507165,
#   'Hedged QA Faithfulness Divergence': 1.2385826887250488},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.5936036473018815,
#   'Calibrated Faithfulness Divergence': 0.6234694392998011,
#   'Original Generalised ECE': 0.3054064276446021,
#   'Calibrated Generalised ECE': 0.1453800300172355,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.2310970809507165,
#   'Hedged QA Faithfulness Divergence': 1.2385826887250488},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.102932093251383,
#   'Calibrated Faithfulness Divergence': 0.7510360282210949,
#   'Original Generalised ECE': 0.3697977204879337,
#   'Calibrated Generalised ECE': 0.2249631955219089,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3473551758638638,
#   'Hedged QA Faithfulness Divergence': 2.1267012887586128},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.102932093251383,
#   'Calibrated Faithfulness Divergence': 0.4801141498458495,
#   'Original Generalised ECE': 0.3697977204879337,
#   'Calibrated Generalised ECE': 0.1761170925663248,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3473551758638638,
#   'Hedged QA Faithfulness Divergence': 2.1267012887586128},
#  {'Dataset': 'SQuAD2.0',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.102932093251383,
#   'Calibrated Faithfulness Divergence': 0.67025748968936,
#   'Original Generalised ECE': 0.3697977204879337,
#   'Calibrated Generalised ECE': 0.1886626171898846,
#   'dataset_size': 130000,
#   'Hedged QA Generalised ECE': 0.3473551758638638,
#   'Hedged QA Faithfulness Divergence': 2.1267012887586128},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 0.5792842290570978,
#   'Calibrated Faithfulness Divergence': 1.1184441310713,
#   'Original Generalised ECE': 0.1518644617754558,
#   'Calibrated Generalised ECE': 0.1281194624858806,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.1407797342576905,
#   'Hedged QA Faithfulness Divergence': 0.753454150356017},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 0.5792842290570978,
#   'Calibrated Faithfulness Divergence': 0.5630323543579844,
#   'Original Generalised ECE': 0.1518644617754558,
#   'Calibrated Generalised ECE': 0.0894012054076972,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.1407797342576905,
#   'Hedged QA Faithfulness Divergence': 0.753454150356017},
#  {'Dataset': 'MMLU',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 0.5792842290570978,
#   'Calibrated Faithfulness Divergence': 1.3333830156071167,
#   'Original Generalised ECE': 0.1518644617754558,
#   'Calibrated Generalised ECE': 0.1381488682371981,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.1407797342576905,
#   'Hedged QA Faithfulness Divergence': 0.753454150356017},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.1983302280034316,
#   'Calibrated Faithfulness Divergence': 0.5567779703103374,
#   'Original Generalised ECE': 0.2393952686417554,
#   'Calibrated Generalised ECE': 0.1195125081630208,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.2976378441427116,
#   'Hedged QA Faithfulness Divergence': 1.6252265862686257},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.1983302280034316,
#   'Calibrated Faithfulness Divergence': 0.47121619094811,
#   'Original Generalised ECE': 0.2393952686417554,
#   'Calibrated Generalised ECE': 0.1129336382279038,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.2976378441427116,
#   'Hedged QA Faithfulness Divergence': 1.6252265862686257},
#  {'Dataset': 'MMLU',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.1983302280034316,
#   'Calibrated Faithfulness Divergence': 0.5784114372102769,
#   'Original Generalised ECE': 0.2393952686417554,
#   'Calibrated Generalised ECE': 0.1090205081699142,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.2976378441427116,
#   'Hedged QA Faithfulness Divergence': 1.6252265862686257},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 0.9252482218502812,
#   'Calibrated Faithfulness Divergence': 0.6016335715768074,
#   'Original Generalised ECE': 0.1900478777748012,
#   'Calibrated Generalised ECE': 0.1201269142691788,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.1921646809596402,
#   'Hedged QA Faithfulness Divergence': 1.035699073373874},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 0.9252482218502812,
#   'Calibrated Faithfulness Divergence': 0.4609362787086137,
#   'Original Generalised ECE': 0.1900478777748012,
#   'Calibrated Generalised ECE': 0.0915096627343768,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.1921646809596402,
#   'Hedged QA Faithfulness Divergence': 1.035699073373874},
#  {'Dataset': 'MMLU',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 0.9252482218502812,
#   'Calibrated Faithfulness Divergence': 0.6647290790237945,
#   'Original Generalised ECE': 0.1900478777748012,
#   'Calibrated Generalised ECE': 0.0964891600853428,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.1921646809596402,
#   'Hedged QA Faithfulness Divergence': 1.035699073373874},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 0.9018993169473468,
#   'Calibrated Faithfulness Divergence': 0.7698166408245688,
#   'Original Generalised ECE': 0.1667240465181014,
#   'Calibrated Generalised ECE': 0.1476279275110361,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.2047028848548391,
#   'Hedged QA Faithfulness Divergence': 1.0980268588041595},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 0.9018993169473468,
#   'Calibrated Faithfulness Divergence': 0.5635527189509251,
#   'Original Generalised ECE': 0.1667240465181014,
#   'Calibrated Generalised ECE': 0.1448006374818205,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.2047028848548391,
#   'Hedged QA Faithfulness Divergence': 1.0980268588041595},
#  {'Dataset': 'MMLU',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 0.9018993169473468,
#   'Calibrated Faithfulness Divergence': 0.6431313966116565,
#   'Original Generalised ECE': 0.1667240465181014,
#   'Calibrated Generalised ECE': 0.112614483339751,
#   'dataset_size': 116000,
#   'Hedged QA Generalised ECE': 0.2047028848548391,
#   'Hedged QA Faithfulness Divergence': 1.0980268588041595},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.2651771441573527,
#   'Calibrated Faithfulness Divergence': 0.677997755319684,
#   'Original Generalised ECE': 0.3923309326778563,
#   'Calibrated Generalised ECE': 0.2298367006156856,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.274593155787019,
#   'Hedged QA Faithfulness Divergence': 1.2922476168028272},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.2651771441573527,
#   'Calibrated Faithfulness Divergence': 0.4750813298421877,
#   'Original Generalised ECE': 0.3923309326778563,
#   'Calibrated Generalised ECE': 0.1786099145422159,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.274593155787019,
#   'Hedged QA Faithfulness Divergence': 1.2922476168028272},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'GPT-OSS-20B',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.2651771441573527,
#   'Calibrated Faithfulness Divergence': 0.6453790604859229,
#   'Original Generalised ECE': 0.3923309326778563,
#   'Calibrated Generalised ECE': 0.2267115693249688,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.274593155787019,
#   'Hedged QA Faithfulness Divergence': 1.2922476168028272},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.781701991624782,
#   'Calibrated Faithfulness Divergence': 0.7101366963634791,
#   'Original Generalised ECE': 0.3740181445492032,
#   'Calibrated Generalised ECE': 0.2273091234891761,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.3289962356292959,
#   'Hedged QA Faithfulness Divergence': 1.4666872616615223},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.781701991624782,
#   'Calibrated Faithfulness Divergence': 0.4769694828200648,
#   'Original Generalised ECE': 0.3740181445492032,
#   'Calibrated Generalised ECE': 0.2376406809287461,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.3289962356292959,
#   'Hedged QA Faithfulness Divergence': 1.4666872616615223},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Mistral-7B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.781701991624782,
#   'Calibrated Faithfulness Divergence': 0.7270842255792598,
#   'Original Generalised ECE': 0.3740181445492032,
#   'Calibrated Generalised ECE': 0.2478583195657958,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.3289962356292959,
#   'Hedged QA Faithfulness Divergence': 1.4666872616615223},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 1.8284753963139375,
#   'Calibrated Faithfulness Divergence': 0.7121433077421214,
#   'Original Generalised ECE': 0.4266761227177914,
#   'Calibrated Generalised ECE': 0.2686759653394905,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.2832219540492913,
#   'Hedged QA Faithfulness Divergence': 0.8578030396246726},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 1.8284753963139375,
#   'Calibrated Faithfulness Divergence': 0.4668259789214957,
#   'Original Generalised ECE': 0.4266761227177914,
#   'Calibrated Generalised ECE': 0.2544532597415606,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.2832219540492913,
#   'Hedged QA Faithfulness Divergence': 0.8578030396246726},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Llama-3.1-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 1.8284753963139375,
#   'Calibrated Faithfulness Divergence': 0.6363884084448393,
#   'Original Generalised ECE': 0.4266761227177914,
#   'Calibrated Generalised ECE': 0.2471196361662431,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.2832219540492913,
#   'Hedged QA Faithfulness Divergence': 0.8578030396246726},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Linguistic Confidence',
#   'Original Faithfulness Divergence': 2.0537941094044863,
#   'Calibrated Faithfulness Divergence': 0.7069332612876178,
#   'Original Generalised ECE': 0.4421168887709607,
#   'Calibrated Generalised ECE': 0.2701187271085545,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.3611064499918773,
#   'Hedged QA Faithfulness Divergence': 1.520837295669656},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Semantic Uncertainty',
#   'Original Faithfulness Divergence': 2.0537941094044863,
#   'Calibrated Faithfulness Divergence': 0.4635585425900997,
#   'Original Generalised ECE': 0.4421168887709607,
#   'Calibrated Generalised ECE': 0.2466558556571673,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.3611064499918773,
#   'Hedged QA Faithfulness Divergence': 1.520837295669656},
#  {'Dataset': 'TruthfulQA',
#   'Model': 'Qwen3-8B-Inst.',
#   'Estimator': 'Token Probability',
#   'Original Faithfulness Divergence': 2.0537941094044863,
#   'Calibrated Faithfulness Divergence': 0.6230594745270341,
#   'Original Generalised ECE': 0.4421168887709607,
#   'Calibrated Generalised ECE': 0.2421380813583741,
#   'dataset_size': 817,
#   'Hedged QA Generalised ECE': 0.3611064499918773,
#   'Hedged QA Faithfulness Divergence': 1.520837295669656}]

# %%
from collections import defaultdict


ESTIMATOR_ORDER = ["Linguistic Confidence", "Semantic Uncertainty", "Token Probability"]

ESTIMATOR_LABELS = {
    "Linguistic Confidence": "Linguistic Conf.",
    "Semantic Uncertainty":  "Semantic Unc.",
    "Token Probability":     "Token Prob.",
}


def _fmt(value: float, decimals: int = 3) -> str:
    return f"{value:.{decimals}f}"


def _arrow(orig: float, calib: float, decimals: int = 3) -> str:
    return f"${_fmt(orig, decimals)} \\to {_fmt(calib, decimals)}$"


def generate_latex_table(
    data: list[dict],
    caption: str = "Calibration results across datasets, models, and estimators. Lower is better for all metrics.",
    label: str = "tab:results",
    decimals: int = 3,
    dataset_order: list[str] | None = None,
    model_order: list[str] | None = None,
) -> str:
    """
    Convert a list of result dicts into a LaTeX table string.

    Args:
        data:          List of result dicts (see module docstring for expected keys).
        caption:       Table caption.
        label:         LaTeX label for \\ref{}.
        decimals:      Decimal places for all numeric values.
        dataset_order: Optional explicit ordering of datasets.
                       Defaults to insertion order found in data.
        model_order:   Optional explicit ordering of models within each dataset.
                       Defaults to insertion order found in data.

    Returns:
        A self-contained LaTeX string (table* environment).
        Required packages: booktabs, multirow, makecell.
    """
    # ── 1. Index data: dataset -> model -> estimator -> row ──────────────────
    index: dict[str, dict[str, dict[str, dict]]] = defaultdict(lambda: defaultdict(dict))
    seen_datasets: list[str] = []
    seen_models: dict[str, list[str]] = defaultdict(list)

    for row in data:
        ds   = row["Dataset"]
        mdl  = row["Model"]
        est  = row["Estimator"]

        if ds not in seen_datasets:
            seen_datasets.append(ds)
        if mdl not in seen_models[ds]:
            seen_models[ds].append(mdl)

        index[ds][mdl][est] = row

    datasets = dataset_order if dataset_order is not None else seen_datasets
    
    def get_models(ds):
        if model_order is not None:
            return [m for m in model_order if m in index[ds]]
        return seen_models[ds]

    # ── 2. Build header ───────────────────────────────────────────────────────
    header = r"""\begin{table*}[ht]
\centering
\caption{""" + caption + r"""}
\label{""" + label + r"""}
\resizebox{\textwidth}{!}{%
\begin{tabular}{llllcccc}
\toprule
\multirow{3}{*}{Dataset}
  & \multirow{3}{*}{Model}
  & \multirow{3}{*}{Estimator}
  & \multicolumn{2}{c}{\textbf{In-Domain Calibration}}
  & \multicolumn{2}{c}{\textbf{Hedged QA}} \\
\cmidrule(lr){4-5} \cmidrule(lr){6-7}
  & & & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Calib.)}
       & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Calib.)}
       & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Hedged)}
       & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Hedged)} \\
\midrule"""

    # ── 3. Build body rows ────────────────────────────────────────────────────
    body_lines: list[str] = []

    for ds_idx, ds in enumerate(datasets):
        models = get_models(ds)
        n_ds_rows = len(models) * len(ESTIMATOR_ORDER)

        ds_cell = f"\\multirow{{{n_ds_rows}}}{{*}}{{{ds}}}"
        first_ds_row = True

        for mdl_idx, mdl in enumerate(models):
            estimators = ESTIMATOR_ORDER

            mdl_cell = f"\\multirow{{{len(estimators)}}}{{*}}{{{mdl}}}"
            first_mdl_row = True

            for est_idx, est in enumerate(estimators):
                row = index[ds][mdl].get(est)
                if row is None:
                    continue

                # In-domain calibration columns (vary per estimator)
                fd_cell  = _arrow(row["Original Faithfulness Divergence"],
                                  row["Calibrated Faithfulness Divergence"], decimals)
                ece_cell = _arrow(row["Original Generalised ECE"],
                                  row["Calibrated Generalised ECE"], decimals)

                # Hedged QA columns (same for all estimators of this model/dataset)
                if first_mdl_row:
                    hfd_cell = (f"\\multirow{{{len(estimators)}}}{{*}}{{"
                                + _arrow(row["Original Faithfulness Divergence"],
                                         row["Hedged QA Faithfulness Divergence"], decimals)
                                + "}")
                    hece_cell = (f"\\multirow{{{len(estimators)}}}{{*}}{{"
                                 + _arrow(row["Original Generalised ECE"],
                                          row["Hedged QA Generalised ECE"], decimals)
                                 + "}")
                else:
                    hfd_cell  = ""
                    hece_cell = ""

                est_label = ESTIMATOR_LABELS.get(est, est)

                # Assemble leading cells
                if first_ds_row and first_mdl_row:
                    leading = f" {ds_cell} & {mdl_cell}"
                elif first_mdl_row:
                    leading = f" & {mdl_cell}"
                else:
                    leading = f" &"

                line = (f"{leading} & {est_label}"
                        f" & {fd_cell} & {ece_cell}"
                        f" & {hfd_cell} & {hece_cell} \\\\")

                body_lines.append(line)
                first_ds_row   = False
                first_mdl_row  = False

            # Separator between models (not after the last model in a dataset)
            if mdl_idx < len(models) - 1:
                body_lines.append(r"\cmidrule(l){2-7}")

        # Separator between datasets (not after the last one)
        if ds_idx < len(datasets) - 1:
            body_lines.append(r"\midrule")

    # ── 4. Footer ─────────────────────────────────────────────────────────────
    footer = r"""\bottomrule
\end{tabular}%
}
\end{table*}"""

    return "\n".join([header, *body_lines, footer])


print(generate_latex_table(combined_df.to_dict("records"), caption="Sample table.", label="tab:sample"))
# Out:
# \begin{table*}[ht]
# \centering
# \caption{Sample table.}
# \label{tab:sample}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{llllcccc}
# \toprule
# \multirow{3}{*}{Dataset}
#   & \multirow{3}{*}{Model}
#   & \multirow{3}{*}{Estimator}
#   & \multicolumn{2}{c}{\textbf{In-Domain Calibration}}
#   & \multicolumn{2}{c}{\textbf{Hedged QA}} \\
# \cmidrule(lr){4-5} \cmidrule(lr){6-7}
#   & & & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Calib.)}
#        & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Calib.)}
#        & \makecell{Faithfulness \\ Divergence \\ (Orig.\ $\to$ Hedged)}
#        & \makecell{Generalised \\ ECE \\ (Orig.\ $\to$ Hedged)} \\
# \midrule
#  \multirow{12}{*}{SQuAD2.0} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $2.265 \to 0.764$ & $0.389 \to 0.232$ & \multirow{3}{*}{$2.265 \to 2.278$} & \multirow{3}{*}{$0.389 \to 0.354$} \\
#  & & Semantic Unc. & $2.265 \to 0.474$ & $0.389 \to 0.137$ &  &  \\
#  & & Token Prob. & $2.265 \to 0.665$ & $0.389 \to 0.192$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $1.978 \to 0.701$ & $0.350 \to 0.185$ & \multirow{3}{*}{$1.978 \to 2.054$} & \multirow{3}{*}{$0.350 \to 0.337$} \\
#  & & Semantic Unc. & $1.978 \to 0.487$ & $0.350 \to 0.116$ &  &  \\
#  & & Token Prob. & $1.978 \to 0.682$ & $0.350 \to 0.181$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $1.594 \to 0.643$ & $0.305 \to 0.160$ & \multirow{3}{*}{$1.594 \to 1.239$} & \multirow{3}{*}{$0.305 \to 0.231$} \\
#  & & Semantic Unc. & $1.594 \to 0.495$ & $0.305 \to 0.122$ &  &  \\
#  & & Token Prob. & $1.594 \to 0.623$ & $0.305 \to 0.145$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $2.103 \to 0.751$ & $0.370 \to 0.225$ & \multirow{3}{*}{$2.103 \to 2.127$} & \multirow{3}{*}{$0.370 \to 0.347$} \\
#  & & Semantic Unc. & $2.103 \to 0.480$ & $0.370 \to 0.176$ &  &  \\
#  & & Token Prob. & $2.103 \to 0.670$ & $0.370 \to 0.189$ &  &  \\
# \midrule
#  \multirow{12}{*}{MMLU} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $0.579 \to 1.118$ & $0.152 \to 0.128$ & \multirow{3}{*}{$0.579 \to 0.753$} & \multirow{3}{*}{$0.152 \to 0.141$} \\
#  & & Semantic Unc. & $0.579 \to 0.563$ & $0.152 \to 0.089$ &  &  \\
#  & & Token Prob. & $0.579 \to 1.333$ & $0.152 \to 0.138$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $1.198 \to 0.557$ & $0.239 \to 0.120$ & \multirow{3}{*}{$1.198 \to 1.625$} & \multirow{3}{*}{$0.239 \to 0.298$} \\
#  & & Semantic Unc. & $1.198 \to 0.471$ & $0.239 \to 0.113$ &  &  \\
#  & & Token Prob. & $1.198 \to 0.578$ & $0.239 \to 0.109$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $0.925 \to 0.602$ & $0.190 \to 0.120$ & \multirow{3}{*}{$0.925 \to 1.036$} & \multirow{3}{*}{$0.190 \to 0.192$} \\
#  & & Semantic Unc. & $0.925 \to 0.461$ & $0.190 \to 0.092$ &  &  \\
#  & & Token Prob. & $0.925 \to 0.665$ & $0.190 \to 0.096$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $0.902 \to 0.770$ & $0.167 \to 0.148$ & \multirow{3}{*}{$0.902 \to 1.098$} & \multirow{3}{*}{$0.167 \to 0.205$} \\
#  & & Semantic Unc. & $0.902 \to 0.564$ & $0.167 \to 0.145$ &  &  \\
#  & & Token Prob. & $0.902 \to 0.643$ & $0.167 \to 0.113$ &  &  \\
# \midrule
#  \multirow{12}{*}{TruthfulQA} & \multirow{3}{*}{GPT-OSS-20B} & Linguistic Conf. & $2.265 \to 0.678$ & $0.392 \to 0.230$ & \multirow{3}{*}{$2.265 \to 1.292$} & \multirow{3}{*}{$0.392 \to 0.275$} \\
#  & & Semantic Unc. & $2.265 \to 0.475$ & $0.392 \to 0.179$ &  &  \\
#  & & Token Prob. & $2.265 \to 0.645$ & $0.392 \to 0.227$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Mistral-7B-Inst.} & Linguistic Conf. & $1.782 \to 0.710$ & $0.374 \to 0.227$ & \multirow{3}{*}{$1.782 \to 1.467$} & \multirow{3}{*}{$0.374 \to 0.329$} \\
#  & & Semantic Unc. & $1.782 \to 0.477$ & $0.374 \to 0.238$ &  &  \\
#  & & Token Prob. & $1.782 \to 0.727$ & $0.374 \to 0.248$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Llama-3.1-8B-Inst.} & Linguistic Conf. & $1.828 \to 0.712$ & $0.427 \to 0.269$ & \multirow{3}{*}{$1.828 \to 0.858$} & \multirow{3}{*}{$0.427 \to 0.283$} \\
#  & & Semantic Unc. & $1.828 \to 0.467$ & $0.427 \to 0.254$ &  &  \\
#  & & Token Prob. & $1.828 \to 0.636$ & $0.427 \to 0.247$ &  &  \\
# \cmidrule(l){2-7}
#  & \multirow{3}{*}{Qwen3-8B-Inst.} & Linguistic Conf. & $2.054 \to 0.707$ & $0.442 \to 0.270$ & \multirow{3}{*}{$2.054 \to 1.521$} & \multirow{3}{*}{$0.442 \to 0.361$} \\
#  & & Semantic Unc. & $2.054 \to 0.464$ & $0.442 \to 0.247$ &  &  \\
#  & & Token Prob. & $2.054 \to 0.623$ & $0.442 \to 0.242$ &  &  \\
# \bottomrule
# \end{tabular}%
# }
# \end{table*}
