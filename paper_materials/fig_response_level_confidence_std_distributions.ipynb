# %%
import sys
sys.path.append("..")
import os
import pandas as pd
import pickle
from tqdm import tqdm
import numpy as np

# %%
methods_names = {
    "dist_linguistic_confidence": "Dist. Ling. Conf.",
    "dist_semantic_uncertainty": "Dist. Semantic Unc.",
    "dist_lnll": "Dist. Token Prob"
}

dataset_size = {
    "mmlu": 14000 / 2,
    "squadv2": 11900,
    "truthful_qa": 817
}

dataset_map = {
    "mmlu": "MMLU",
    "squadv2": "SQuAD2.0",
    "truthful_qa": "TruthfulQA"
}

model_name_map = {
    "Llama-3.1-8B-Instruct": "Llama-3.1-8B-Inst.",
    "Meta-Llama-3-8B-Instruct": "Llama-3-8B-Inst.",
    "Qwen3-8B": "Qwen3-8B-Inst.",
    "Mistral-7B-Instruct-v0.3": "Mistral-7B-Inst.",
    "gpt-oss-20b": "GPT-OSS-20B",
    "gpt-oss-120b": "GPT-OSS-120B",
    "gemma-4-31B-it": "Gemma-4-31B-It.",
    "Qwen3-235B-A22B-Instruct-2507-tput": "Qwen3-235B-Inst."
}

# %%
def _leaf_dirs(root_dir):
    leaf_dirs = []
    for root, dirs, files in os.walk(root_dir):
        if not dirs:
            leaf_dirs.append(root)
    return sorted(leaf_dirs)

def extract_sigma(string: str) -> float:
    # Extract the number after "sigma=" and before the next comma or end of string
    import re
    match = re.search(r"sigma=([\d\.]+)", string)
    if match:
        return float(match.group(1))
    else:
        raise ValueError(f"Could not extract sigma from string: {string}")


models = []
datasets = []

sigma_map = {
    "Linguistic Confidence": [],
    "Token Probability": [],
    "Semantic Uncertainty": []
}

dataset_instance_counts = {dataset: 0 for dataset in dataset_map.keys()}

for dataset in dataset_map.keys():
    lc = f"/hdd/ivny/results/{dataset}/direct_qa_unified_lc"
    tp = f"/hdd/ivny/results/{dataset}/direct_qa_unified_tp"
    su = f"/hdd/ivny/results/{dataset}/direct_qa_unified_su"

    lc_leaf_dirs = _leaf_dirs(lc)
    tp_leaf_dirs = _leaf_dirs(tp)
    su_leaf_dirs = _leaf_dirs(su)

    for lc_, tp_, su_ in zip(lc_leaf_dirs, tp_leaf_dirs, su_leaf_dirs):
        try:
            lc_conf_path = os.path.join(lc_, "eval_details.csv")
            tp_conf_path = os.path.join(tp_, "eval_details.csv")
            su_conf_path = os.path.join(su_, "eval_details.csv")

            lc_sigmas = pd.read_csv(lc_conf_path)["confidence_0"].apply(extract_sigma).tolist()
            tp_sigmas = pd.read_csv(tp_conf_path)["confidence_0"].apply(extract_sigma).tolist()
            su_sigmas = pd.read_csv(su_conf_path)["confidence_0"].apply(extract_sigma).tolist()

            sigma_map["Linguistic Confidence"].extend(lc_sigmas)
            sigma_map["Token Probability"].extend(tp_sigmas)
            sigma_map["Semantic Uncertainty"].extend(su_sigmas)
        except Exception as e:
            print(f"Error processing {lc_}, {tp_}, {su_}: {e}")
# Out:
# Error processing /hdd/ivny/results/mmlu/direct_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-58-16, /hdd/ivny/results/mmlu/direct_qa_unified_tp/google/gemma-4-31B-it/2026-04-26_00-16-54, /hdd/ivny/results/mmlu/direct_qa_unified_su/google/gemma-4-31B-it/2026-04-26_00-18-56: [Errno 2] No such file or directory: '/hdd/ivny/results/mmlu/direct_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-58-16/eval_details.csv'
# Error processing /hdd/ivny/results/mmlu/direct_qa_unified_lc/google/gemma-4-31B-it/retrieved, /hdd/ivny/results/mmlu/direct_qa_unified_tp/mistralai/Mistral-7B-Instruct-v0.3/2026-04-20_13-36-01, /hdd/ivny/results/mmlu/direct_qa_unified_su/mistralai/Mistral-7B-Instruct-v0.3/2026-04-20_13-55-23: [Errno 2] No such file or directory: '/hdd/ivny/results/mmlu/direct_qa_unified_lc/google/gemma-4-31B-it/retrieved/eval_details.csv'
# Error processing /hdd/ivny/results/mmlu/direct_qa_unified_lc/mistralai/Mistral-7B-Instruct-v0.3/2026-04-20_05-13-18, /hdd/ivny/results/mmlu/direct_qa_unified_tp/openai/gpt-oss-20b/2026-04-20_13-20-08, /hdd/ivny/results/mmlu/direct_qa_unified_su/openai/gpt-oss-20b/2026-04-20_13-54-22: 'confidence_0'
# Error processing /hdd/ivny/results/mmlu/direct_qa_unified_lc/openai/gpt-oss-120b/2026-04-19_03-27-05, /hdd/ivny/results/mmlu/direct_qa_unified_tp/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-26_00-16-03, /hdd/ivny/results/mmlu/direct_qa_unified_su/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-26_00-18-13: 'confidence_0'
# Error processing /hdd/ivny/results/squadv2/direct_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-55-37, /hdd/ivny/results/squadv2/direct_qa_unified_tp/google/gemma-4-31B-it/2026-04-26_00-24-26, /hdd/ivny/results/squadv2/direct_qa_unified_su/google/gemma-4-31B-it/2026-04-26_00-27-03: [Errno 2] No such file or directory: '/hdd/ivny/results/squadv2/direct_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-55-37/eval_details.csv'
# Error processing /hdd/ivny/results/squadv2/direct_qa_unified_lc/google/gemma-4-31B-it/retrieved, /hdd/ivny/results/squadv2/direct_qa_unified_tp/mistralai/Mistral-7B-Instruct-v0.3/2026-04-20_12-57-12, /hdd/ivny/results/squadv2/direct_qa_unified_su/mistralai/Mistral-7B-Instruct-v0.3/2026-04-20_13-15-32: [Errno 2] No such file or directory: '/hdd/ivny/results/squadv2/direct_qa_unified_lc/google/gemma-4-31B-it/retrieved/eval_details.csv'
# Error processing /hdd/ivny/results/squadv2/direct_qa_unified_lc/openai/gpt-oss-120b/2026-04-19_03-30-14, /hdd/ivny/results/squadv2/direct_qa_unified_tp/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-26_00-23-26, /hdd/ivny/results/squadv2/direct_qa_unified_su/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-26_00-26-05: 'confidence_0'
# Error processing /hdd/ivny/results/truthful_qa/direct_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-53-11, /hdd/ivny/results/truthful_qa/direct_qa_unified_tp/google/gemma-4-31B-it/2026-04-26_00-47-38, /hdd/ivny/results/truthful_qa/direct_qa_unified_su/google/gemma-4-31B-it/2026-04-26_00-48-29: [Errno 2] No such file or directory: '/hdd/ivny/results/truthful_qa/direct_qa_unified_lc/google/gemma-4-31B-it/2026-04-19_23-53-11/eval_details.csv'
# Error processing /hdd/ivny/results/truthful_qa/direct_qa_unified_lc/google/gemma-4-31B-it/retrieved, /hdd/ivny/results/truthful_qa/direct_qa_unified_tp/mistralai/Mistral-7B-Instruct-v0.3/2026-04-20_01-00-39, /hdd/ivny/results/truthful_qa/direct_qa_unified_su/mistralai/Mistral-7B-Instruct-v0.3/2026-04-20_01-10-19: [Errno 2] No such file or directory: '/hdd/ivny/results/truthful_qa/direct_qa_unified_lc/google/gemma-4-31B-it/retrieved/eval_details.csv'
# Error processing /hdd/ivny/results/truthful_qa/direct_qa_unified_lc/openai/gpt-oss-120b/2026-04-19_03-22-04, /hdd/ivny/results/truthful_qa/direct_qa_unified_tp/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-26_00-47-21, /hdd/ivny/results/truthful_qa/direct_qa_unified_su/qwen/Qwen3-235B-A22B-Instruct-2507-tput/2026-04-26_00-48-12: 'confidence_0'

# %%
import matplotlib.pyplot as plt
import numpy as np

keys = list(sigma_map.keys())
fig, axes = plt.subplots(1, 3, figsize=(9, 3), sharey=False)

for ax, key in zip(axes, keys):
    values = sigma_map.get(key, [])
    ax.hist(values, bins=40, color="#4C78A8", alpha=0.8, edgecolor="white", density=True)

    mean_val = float(np.mean(values)) if len(values) > 0 else np.nan
    if np.isfinite(mean_val):
        ax.axvline(
            mean_val,
            color="red",
            linestyle="-",
            linewidth=1.8,
            alpha=0.9,
            label=f"Mean: {mean_val:.3f}",
        )
        ax.legend(loc="upper right", frameon=False, fontsize=8)

    ax.set_title(key)
    ax.set_xlabel("Response-level Standard Deviation")
    ax.grid(alpha=0.2, linestyle="--")

axes[0].set_ylabel("Density")
plt.tight_layout()
plt.savefig("figs/response_level_confidence_std_distributions.pdf", dpi=300, bbox_inches="tight")
