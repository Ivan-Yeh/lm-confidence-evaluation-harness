# %%
import sys
sys.path.append("..")
import numpy as np
import pickle

from lm_conf.default_utils.custom_types import OrganisedOutputs
from lm_conf.post_processing.metrics import BetaDistribution
from lm_conf.post_processing.metrics import dAUROC, dECE_equal_mass, dECE_equal_width

# %%
with open("../results/trivia_qa/dist_lnll/meta-llama/Meta-Llama-3-8B-Instruct/2025-12-24_00-52-05/graded_outputs_0.pkl", "rb") as f:
    graded_outputs: OrganisedOutputs = pickle.load(f)

# %%
dAUROC({}, graded_outputs)
