# %%
from scipy.stats import beta

# %%
# Sample 10 random values from a beta distribution
samples = beta.rvs(0.21, 0.9, size=10)
print(samples)
# Out:
# [4.82307917e-06 2.87957878e-07 1.53946785e-01 8.96578875e-01
#  5.92809484e-01 7.63159654e-04 7.50186551e-02 3.74199035e-01
#  7.33813051e-03 1.89721207e-02]
